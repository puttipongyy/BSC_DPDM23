# %% [markdown]
# <a href="https://colab.research.google.com/github/puttipongyy/BSC_DPDM23/blob/main/Frequent_Patterns_(Association_Rules).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/BSC_DPDM23'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(os.path.join(path,'reduced_marketbasket.csv'),encoding='latin-1')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# Quiz: ข้อมูลมาจากกี่ประเทศ

# %%
len(set(data['Country']))
# Out:
# 38

# %%
data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# # แปลง data ให้อยู่ในรูปแบบ Transaction data ด้วย *groupby.apply(list)*

# %%
data.groupby('InvoiceNo')['StockCode'].apply(list)
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %%
transactions = data.groupby('InvoiceNo')['StockCode'].apply(list)

# %% [markdown]
# ## Association Rules

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.10/dist-packages (1.1.2)

# %%
from apyori import apriori

# %%
apriori(transactions,min_support = 0.5)
# Out:
# <generator object apriori at 0x78ff81b9b680>

# %%
list(apriori(transactions,min_support = 0.065))
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
frequentItemsets = list(apriori(transactions,min_support = 0.065))
frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
len(frequentItemsets)
# Out:
# 4

# %%
frequentItemsets[0]
# Out:
# RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)])

# %%
frequentItemsets[0][0]
# Out:
# frozenset({'22423'})

# %%
dir(frequentItemsets[0][0])
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'copy',
#  'difference',
#  'intersection',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'symmetric_difference',
#  'union']

# %%
frequentItemsets[0][0].__len__()
# Out:
# 1

# %%
min_sup = 0.03

frequentItemsets = list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22386', '85099B'}), support=0.03216216216216216, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0), OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335), OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])
# yes
# RelationRecord(items=frozenset({'22697', '22699'}), support=0.03027027027027027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22697', '22699'}), confidence=0.03027027027027027, lift=1.0), OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947), OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %% [markdown]
# RelationRecord(items=frozenset({'22386', '85099B'}),
#
# support=0.03216216216216216,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335),
#
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])

# %%
set(data[(data['StockCode']=='22386') | (data['StockCode']=='85099B') | (data['StockCode']=='22699') | (data['StockCode']=='22697') ]['Description'])
# Out:
# {'GREEN REGENCY TEACUP AND SAUCER',
#  'JUMBO BAG PINK POLKADOT',
#  'JUMBO BAG RED RETROSPOT',
#  'ROSES REGENCY TEACUP AND SAUCER '}

# %% [markdown]
# Quiz <br>
# stock code 22386 and 85099B คือสินค้าอะไร

# %%
set(data[(data['StockCode']=='22386')]['Description'])
# Out:
# {'JUMBO BAG PINK POLKADOT'}

# %%
set(data[(data['StockCode']=='85099B')]['Description'])
# Out:
# {'JUMBO BAG RED RETROSPOT'}

# %% [markdown]
# RelationRecord(items=frozenset({'22699', '22697'}), support=0.03027027027027027,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22699', '22697'}), confidence=0.03027027027027027, lift=1.0),
# <br>
# <br>
#
# OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947),
#
# OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %%
set(data[(data['StockCode']=='22699') | (data['StockCode']=='22697')]['InvoiceNo'])
# Out:
# {'537738',
#  '549951',
#  '557782',
#  '552247',
#  '565424',
#  '556821',
#  '539468',
#  '545526',
#  '581170',
#  '548894',
#  '537645',
#  '579503',
#  '545601',
#  '545333',
#  '576202',
#  '545681',
#  '545215',
#  '574856',
#  '578331',
#  '565849',
#  '564714',
#  '567128',
#  '544768',
#  '546643',
#  '578031',
#  '553768',
#  '545701',
#  '549592',
#  '563896',
#  '544314',
#  '549294',
#  '562770',
#  '573125',
#  '548210',
#  '558918',
#  '555327',
#  '539465',
#  '566091',
#  '571713',
#  'C567358',
#  '546896',
#  '550500',
#  '571550',
#  '550186',
#  '556082',
#  '564057',
#  '549525',
#  '566193',
#  '578833',
#  '548212',
#  '554935',
#  '541495',
#  '555854',
#  '581345',
#  '546008',
#  '541592',
#  '548516',
#  'C541822',
#  '559497',
#  'C537834',
#  '556501',
#  '549730',
#  '570834',
#  '542349',
#  '544301',
#  '562353',
#  '566871',
#  '557642',
#  '538660',
#  '556826',
#  '555277',
#  '552867',
#  '568553',
#  '539594',
#  '541219',
#  '572229',
#  '552557',
#  '557211',
#  '565841',
#  '555158',
#  '577400',
#  '543754',
#  '565862',
#  '556927',
#  '570270',
#  '536804',
#  '581439',
#  '569570',
#  '555147',
#  '571797',
#  '544824',
#  '546760',
#  '545036',
#  'C545449',
#  '540839',
#  '560580',
#  '569415',
#  '580053',
#  '544893',
#  '541969',
#  '567157',
#  '543370',
#  '550213',
#  '572758',
#  '557350',
#  '546683',
#  '571937',
#  '574088',
#  '577078',
#  '563076',
#  '572549',
#  '553661',
#  '578314',
#  '552449',
#  '550333',
#  '537176',
#  '545022',
#  '571283',
#  '559357',
#  '576618',
#  '543602',
#  '550437',
#  '566255',
#  'C559667',
#  '577531',
#  '579012',
#  '541008',
#  '553461',
#  'C545438',
#  'C550808',
#  '541110',
#  'C565848',
#  '552642',
#  'C577752',
#  '581219',
#  '537313',
#  '555278',
#  '564723',
#  '569650',
#  '576651',
#  '577319',
#  '548409',
#  '556917',
#  '567663',
#  '540259',
#  '536876',
#  'C545828',
#  '577258',
#  '552323',
#  '565155',
#  '537534',
#  '541130',
#  '573397',
#  '552493',
#  '550210',
#  '559557',
#  '558035',
#  '563931',
#  '542087',
#  '548522',
#  '558540',
#  '571931',
#  '574852',
#  '544305',
#  '575515',
#  '579938',
#  '565779',
#  '544664',
#  '565519',
#  '575946',
#  '551286',
#  '539492',
#  '559493',
#  '565724',
#  '539741',
#  '563906',
#  'C562375',
#  '563584',
#  '572550',
#  '566395',
#  '542717',
#  '576063',
#  '563909',
#  'C542263',
#  '555276',
#  'C564854',
#  '573388',
#  '542779',
#  '544095',
#  '550953',
#  '559817',
#  '568411',
#  '541695',
#  '561702',
#  '559693',
#  '562282',
#  '559886',
#  '547063',
#  '554040',
#  '567184',
#  '565838',
#  '556323',
#  '579885',
#  '547826',
#  '554798',
#  '552715',
#  '557431',
#  '544067',
#  '567673',
#  '547249',
#  '540664',
#  '547042',
#  '555722',
#  '552975',
#  '548559',
#  '562157',
#  '567280',
#  '579102',
#  '575932',
#  '542221',
#  'C556635',
#  '558923',
#  '562849',
#  '566788',
#  'C551465',
#  '537179',
#  '570700',
#  '577610',
#  '565150',
#  '537042',
#  '552663',
#  '563561',
#  '566572',
#  '544596',
#  '549746',
#  '551174',
#  '566607',
#  '553535',
#  '537754',
#  '571746',
#  '561820',
#  '547399',
#  '551062',
#  'C562921',
#  '571257',
#  '554643',
#  '555109',
#  '553541',
#  '575477',
#  '576255',
#  '543188',
#  '547712',
#  '539752',
#  '537830',
#  '565675',
#  '566720',
#  '581122',
#  '551334',
#  '558120',
#  '543487',
#  'C545456',
#  '550251',
#  '557500',
#  '538524',
#  '538071',
#  '542115',
#  '539739',
#  '547938',
#  '562711',
#  'C566084',
#  '577512',
#  '564172',
#  '547949',
#  '570374',
#  '546158',
#  '571714',
#  '552825',
#  '554113',
#  '548191',
#  '550613',
#  '566124',
#  '566559',
#  '545410',
#  '540915',
#  'C558434',
#  '537666',
#  '545445',
#  '540372',
#  '552257',
#  '546212',
#  '539434',
#  '568574',
#  '564306',
#  '569230',
#  '563910',
#  '559173',
#  '575607',
#  '561633',
#  '567341',
#  'C544665',
#  '556205',
#  '542389',
#  '565916',
#  '543826',
#  '543045',
#  '566477',
#  '556264',
#  '558774',
#  '572082',
#  '568781',
#  '537470',
#  '564552',
#  '564432',
#  '565331',
#  '553387',
#  '570227',
#  '562843',
#  '549222',
#  '556953',
#  '561236',
#  '552710',
#  '554036',
#  '560357',
#  'C567885',
#  '561455',
#  'C551511',
#  'C545525',
#  '539609',
#  '569137',
#  '558068',
#  '566400',
#  '570258',
#  '543546',
#  '549192',
#  '546498',
#  '548734',
#  '566581',
#  '566577',
#  'C561232',
#  '572028',
#  '558873',
#  '570465',
#  '547493',
#  '553013',
#  '568060',
#  '561926',
#  '565056',
#  '554372',
#  '554039',
#  'C569911',
#  '573778',
#  '562377',
#  '575484',
#  '544940',
#  '577298',
#  '577355',
#  '569737',
#  '556767',
#  '566236',
#  '550899',
#  '556636',
#  '572552',
#  '558565',
#  '542691',
#  '545428',
#  '556284',
#  '553684',
#  '573553',
#  'C553479',
#  '569544',
#  '563569',
#  '553718',
#  '553002',
#  '576181',
#  '560036',
#  '543530',
#  '540005',
#  '551825',
#  'C542413',
#  '548739',
#  '568908',
#  '543909',
#  '549852',
#  '558119',
#  '558240',
#  '577316',
#  '536627',
#  '536865',
#  '578936',
#  '581495',
#  '571061',
#  '548373',
#  '580526',
#  '553575',
#  '551885',
#  '561631',
#  '551994',
#  '545474',
#  '543107',
#  '575742',
#  '571446',
#  '550458',
#  '567368',
#  '579694',
#  '566257',
#  '542255',
#  '564817',
#  '565117',
#  '544657',
#  '562608',
#  '559639',
#  'C555598',
#  '550314',
#  '548768',
#  '548718',
#  'C552698',
#  '550968',
#  '554013',
#  '562573',
#  '542862',
#  'C548485',
#  'C549840',
#  '571034',
#  '542719',
#  '541960',
#  '560225',
#  '554382',
#  '546315',
#  '553891',
#  '541220',
#  '545063',
#  '565726',
#  '573266',
#  '561645',
#  '560236',
#  '579267',
#  '560976',
#  '553942',
#  '553462',
#  '570459',
#  '578817',
#  '550914',
#  '555510',
#  '559941',
#  '547830',
#  '557301',
#  '545812',
#  '552694',
#  '553202',
#  '556095',
#  '566597',
#  'C558312',
#  '558770',
#  '562202',
#  '549999',
#  '537378',
#  '575875',
#  '570677',
#  '566988',
#  '576381',
#  '544767',
#  '545460',
#  '557968',
#  '581059',
#  '554054',
#  '566060',
#  '548714',
#  '544660',
#  '559942',
#  '537638',
#  '556813',
#  '565840',
#  '547107',
#  '548974',
#  '548808',
#  '552734',
#  'C562953',
#  '549124',
#  '565234',
#  '542999',
#  '540364',
#  'C564212',
#  '552540',
#  '569419',
#  '543036',
#  '566985',
#  '566537',
#  '578344',
#  '547498',
#  '544205',
#  '580774',
#  '549435',
#  '547788',
#  '556237',
#  '555925',
#  '547385',
#  '560826',
#  'C567955',
#  '560777',
#  '543989',
#  '579187',
#  '561651',
#  '564199',
#  'C537853',
#  '541576',
#  '569918',
#  '542527',
#  '540418',
#  '562222',
#  '557560',
#  '559134',
#  '577020',
#  '545759',
#  '550986',
#  '544833',
#  '561637',
#  '572854',
#  '550499',
#  '545690',
#  '565151',
#  '548733',
#  '537335',
#  '552843',
#  '543019',
#  '547360',
#  '562950',
#  '565919',
#  '574368',
#  '573822',
#  '552270',
#  '549595',
#  '545154',
#  '574334',
#  '565781',
#  '540464',
#  '542632',
#  '558315',
#  '541811',
#  '541859',
#  '552678',
#  '547397',
#  '551173',
#  '543106',
#  '552302',
#  '558443',
#  '546837',
#  '546136',
#  '551997',
#  'C554330',
#  '546096',
#  '539742',
#  '577618',
#  '543629',
#  '551387',
#  'C543633',
#  '550921',
#  '548663',
#  '564825',
#  '542583',
#  '552308',
#  '545014',
#  '544394',
#  '543116',
#  '548726',
#  '551005',
#  '546891',
#  '554326',
#  '574731',
#  '552232',
#  'C539467',
#  '568651',
#  '568676',
#  '581135',
#  '551995',
#  '546688',
#  '545020',
#  '561933',
#  '557973',
#  '544338',
#  '553369',
#  '549909',
#  '579445',
#  '558681',
#  '545320',
#  '537642',
#  '556577',
#  '543013',
#  '550201',
#  'C550664',
#  '569367',
#  '559827',
#  '550470',
#  '541584',
#  '567656',
#  '558348',
#  '540352',
#  '581498',
#  '549056',
#  '553899',
#  '567336',
#  '560773',
#  'C564964',
#  '539708',
#  '568048',
#  '572092',
#  '538951',
#  '542629',
#  '549927',
#  '570514',
#  '567639',
#  '547248',
#  '545945',
#  '560634',
#  '537385',
#  '561051',
#  '550987',
#  '563534',
#  '569545',
#  '581472',
#  '576840',
#  '556256',
#  '573083',
#  '563166',
#  '539736',
#  '580729',
#  '545032',
#  '558030',
#  '558089',
#  '569888',
#  '544778',
#  '573580',
#  '578354',
#  '552687',
#  '575176',
#  '578273',
#  '546927',
#  '557616',
#  '566290',
#  '570872',
#  '546442',
#  '541506',
#  '543732',
#  '564755',
#  '552804',
#  '568955',
#  '560398',
#  'C538059',
#  '542729',
#  '571305',
#  '542881',
#  '568199',
#  '550915',
#  '566600',
#  '554557',
#  '555870',
#  '551171',
#  '551057',
#  '559112',
#  '538880',
#  '581433',
#  '547400',
#  '556016',
#  '545467',
#  '556083',
#  '560246',
#  '546980',
#  '543451',
#  '570388',
#  'C555253',
#  '554958',
#  '555275',
#  '555594',
#  '552730',
#  '544186',
#  '574739',
#  'C545444',
#  '556206',
#  '572751',
#  '557481',
#  '552816',
#  '573020',
#  '547386',
#  '568065',
#  '558864',
#  '542590',
#  '544569',
#  '537955',
#  '550265',
#  '562429',
#  '536523',
#  '568792',
#  '573511',
#  '542647',
#  '555695',
#  '563613',
#  '554030',
#  '564838',
#  '554842',
#  '553035',
#  '567378',
#  '539436',
#  '547580',
#  '547250',
#  '558116',
#  '539735',
#  '568654',
#  '544075',
#  '536544',
#  '567324',
#  '562534',
#  '554813',
#  '544421',
#  '579572',
#  '540465',
#  '551531',
#  '545343',
#  '550307',
#  '568655',
#  '551657',
#  '580066',
#  '552259',
#  '545377',
#  '551343',
#  '542622',
#  '562607',
#  'C538124',
#  '556459',
#  '537240',
#  '548333',
#  '578149',
#  '561698',
#  '553607',
#  '549016',
#  '566603',
#  '537823',
#  '567140',
#  '572655',
#  '575739',
#  '562033',
#  '543533',
#  '544681',
#  '564541',
#  '551960',
#  '555477',
#  '568310',
#  '568369',
#  '539587',
#  '576690',
#  '546752',
#  '544913',
#  '550978',
#  '552315',
#  '543399',
#  '544887',
#  '537022',
#  'C556880',
#  '544081',
#  '580665',
#  'C559949',
#  '551599',
#  '543923',
#  '564835',
#  '567793',
#  '549750',
#  '571546',
#  '572897',
#  '562553',
#  '541280',
#  '553191',
#  '579518',
#  '539451',
#  '564974',
#  '571241',
#  '551564',
#  '568057',
#  '542600',
#  '572613',
#  '539564',
#  '555871',
#  '560780',
#  '561209',
#  '562933',
#  '567922',
#  '559494',
#  'C555254',
#  '562934',
#  '567528',
#  '564837',
#  '561371',
#  '549997',
#  '543277',
#  '565289',
#  '558526',
#  '577071',
#  '559124',
#  '569524',
#  '562713',
#  '567670',
#  '559938',
#  '574893',
#  '539437',
#  '556503',
#  '568988',
#  '561714',
#  '551953',
#  '558262',
#  '577518',
#  '559679',
#  '570701',
#  '538370',
#  '548860',
#  '577594',
#  '537887',
#  '574076',
#  '573330',
#  '544207',
#  '540646',
#  '552324',
#  '555400',
#  '563193',
#  '563951',
#  '575703',
#  '543022',
#  '558372',
#  '562264',
#  '536530',
#  '577358',
#  'C577388',
#  '578347',
#  '580367',
#  '562955',
#  '543532',
#  '554337',
#  '538903',
#  '556416',
#  '548893',
#  '558885',
#  '580669',
#  '538862',
#  '574950',
#  'C552016',
#  '544888',
#  '551058',
#  '545426',
#  '537237',
#  '547547',
#  '541423',
#  '563442',
#  'C549315',
#  '556243',
#  '572274',
#  '548983',
#  '540539',
#  '577691',
#  '536862',
#  '578827',
#  '542619',
#  '573320',
#  '544055',
#  '555499',
#  '557262',
#  '573338',
#  '579512',
#  '562273',
#  '542344',
#  '550302',
#  '564300',
#  '580612',
#  '559295',
#  '559489',
#  '545340',
#  '570650',
#  '575947',
#  '581006',
#  '553162',
#  '555486',
#  '558103',
#  '559878',
#  '559510',
#  '552614',
#  '569917',
#  '545895',
#  '567293',
#  '568193',
#  '573585',
#  'C579945',
#  '541133',
#  '563477',
#  '544677',
#  '561217',
#  '539738',
#  '546888',
#  '551717',
#  '578844',
#  '578044',
#  '553385',
#  '541497',
#  '540848',
#  '570713',
#  '544339',
#  '564754',
#  '538883',
#  '568567',
#  'C545033',
#  '554694',
#  '558904',
#  '568333',
#  '557493',
#  '565994',
#  '562717',
#  '546849',
#  '554483',
#  '571560',
#  '565847',
#  '546314',
#  '567905',
#  '560590',
#  '549296',
#  '579196',
#  '541129',
#  '548547',
#  '555574',
#  '541870',
#  '540154',
#  '545214',
#  '575063',
#  '544684',
#  'C546125',
#  '575185',
#  '579508',
#  '550205',
#  '569496',
#  '574707',
#  '561891',
#  '568804',
#  '566326',
#  '577597',
#  '576339',
#  '576644',
#  '547387',
#  '565223',
#  '576246',
#  '550215',
#  'C539071',
#  '560604',
#  '575324',
#  'C562119',
#  '545464',
#  '565396',
#  '560895',
#  '579751',
#  '549305',
#  '551944',
#  '565214',
#  '553546',
#  '578993',
#  '554560',
#  '552231',
#  '557788',
#  'C566167',
#  'C555358',
#  '575490',
#  '554974',
#  '550471',
#  'C543837',
#  '569202',
#  '570688',
#  '575931',
#  '539593',
#  '559052',
#  '575866',
#  '554026',
#  'C556793',
#  '541932',
#  '575206',
#  '545667',
#  '547378',
#  '562113',
#  '572553',
#  '562166',
#  '553870',
#  '545429',
#  'C562147',
#  '545543',
#  '543097',
#  '545912',
#  '541132',
#  '540907',
#  '546915',
#  '559337',
#  '543660',
#  '551414',
#  '581217',
#  '561329',
#  '539635',
#  '546992',
#  '544434',
#  '566482',
#  '559800',
#  '553869',
#  ...}

# %%
data[data['InvoiceNo']=='562950']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 297488    562950     22752        SET 7 BABUSHKA NESTING BOXES         2
# 297489    562950     22755     SMALL PURPLE BABUSHKA NOTEBOOK         12
# 297490    562950     22753     SMALL YELLOW BABUSHKA NOTEBOOK         12
# 297491    562950     22754        SMALL RED BABUSHKA NOTEBOOK         12
# 297492    562950     22757        LARGE RED BABUSHKA NOTEBOOK         12
# 297493    562950     22758    LARGE PURPLE BABUSHKA NOTEBOOK          12
# 297494    562950     22756     LARGE YELLOW BABUSHKA NOTEBOOK         12
# 297495    562950     23310             BUBBLEGUM RING ASSORTED        36
# 297496    562950     23280  FOLDING BUTTERFLY MIRROR HOT PINK         12
# 297497    562950     22383              LUNCH BAG SUKI DESIGN         10
# 297498    562950     22492             MINI PAINT SET VINTAGE         36
# 297499    562950     71459      HANGING JAM JAR T-LIGHT HOLDER        12
# 297500    562950     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 297501    562950     21175         GIN + TONIC DIET METAL SIGN        12
# 297502    562950     23164                  REGENCY CAKE SLICE         4
# 297503    562950     23245          SET OF 3 REGENCY CAKE TINS         4
# 297504    562950     23171            REGENCY TEA PLATE GREEN         12
# 297505    562950     22697     GREEN REGENCY TEACUP AND SAUCER         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 297488  08/11/2011 09:56       8.50     15608.0  United Kingdom
# 297489  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297490  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297491  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297492  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297493  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297494  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297495  08/11/2011 09:56       0.42     15608.0  United Kingdom
# 297496  08/11/2011 09:56       0.83     15608.0  United Kingdom
# 297497  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297498  08/11/2011 09:56       0.65     15608.0  United Kingdom
# 297499  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297500  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297501  08/11/2011 09:56       2.55     15608.0  United Kingdom
# 297502  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297503  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297504  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297505  08/11/2011 09:56       2.95     15608.0  United Kingdom

# %%
len(transactions)
# Out:
# 25900

# %%
data[data['Quantity']<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 141     12/01/2010 09:41      27.50     14527.0  United Kingdom
# 154     12/01/2010 09:49       4.65     15311.0  United Kingdom
# 235     12/01/2010 10:24       1.65     17548.0  United Kingdom
# 236     12/01/2010 10:24       0.29     17548.0  United Kingdom
# 237     12/01/2010 10:24       0.29     17548.0  United Kingdom
# ...                  ...        ...         ...             ...
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
# 541541  12/09/2011 10:28     224.69     15498.0  United Kingdom
# 541715  12/09/2011 11:57      10.95     15311.0  United Kingdom
# 541716  12/09/2011 11:58       1.25     17315.0  United Kingdom
# 541717  12/09/2011 11:58       1.25     17315.0  United Kingdom
#
# [10624 rows x 8 columns]

# %% [markdown]
# #HW 1 หา Frequent Item Set และ Association Rules
# * ของช่วงเวลา Christmas & New Year (1 Dec - 31 Dec)
# * ของประเทศในทวีป Europe
# * ของช่วงเวลา ตรุษจีน ในทวีป Asia  (15 Jan - 15 Feb)
# * ของช่วงเวลา  Christmas & New Year ในทวีป Europe (1 Dec - 31 Dec)
# * ของวันวาเลนไทน์
# * โดยจัดกลุ่มตามประเทศ + เดือน

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom

# %%
data_HW = data.copy()
data_HW
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# Given data
countries = ['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
             'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
             'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
             'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
             'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
             'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
             'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
             'European Community', 'Malta', 'RSA']

# Fictional mapping of countries to continents (replace with accurate data)
continent_mapping = {
    'United Kingdom': 'Europe',
    'France': 'Europe',
    'Australia': 'Oceania',
    'Netherlands': 'Europe',
    'Germany': 'Europe',
    'Norway': 'Europe',
    'EIRE': 'Europe',
    'Switzerland': 'Europe',
    'Spain': 'Europe',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Italy': 'Europe',
    'Belgium': 'Europe',
    'Lithuania': 'Europe',
    'Japan': 'Asia',
    'Iceland': 'Europe',
    'Channel Islands': 'Europe',
    'Denmark': 'Europe',
    'Cyprus': 'Europe',
    'Sweden': 'Europe',
    'Austria': 'Europe',
    'Israel': 'Asia',
    'Finland': 'Europe',
    'Bahrain': 'Asia',
    'Greece': 'Europe',
    'Hong Kong': 'Asia',
    'Singapore': 'Asia',
    'Lebanon': 'Asia',
    'United Arab Emirates': 'Asia',
    'Saudi Arabia': 'Asia',
    'Czech Republic': 'Europe',
    'Canada': 'North America',
    'Unspecified': 'Unknown',
    'Brazil': 'South America',
    'USA': 'North America',
    'European Community': 'Europe',
    'Malta': 'Europe',
    'RSA': 'Africa'
}

# Create a DataFrame
data_continent = {'Country': countries, 'Continent': [continent_mapping.get(country, 'Unknown') for country in countries]}
df_continent = pd.DataFrame(data_continent)

# Display the DataFrame
df_continent.head()
# Out:
#           Country Continent
# 0  United Kingdom    Europe
# 1          France    Europe
# 2       Australia   Oceania
# 3     Netherlands    Europe
# 4         Germany    Europe

# %%
df_continent
# Out:
#                  Country      Continent
# 0         United Kingdom         Europe
# 1                 France         Europe
# 2              Australia        Oceania
# 3            Netherlands         Europe
# 4                Germany         Europe
# 5                 Norway         Europe
# 6                   EIRE         Europe
# 7            Switzerland         Europe
# 8                  Spain         Europe
# 9                 Poland         Europe
# 10              Portugal         Europe
# 11                 Italy         Europe
# 12               Belgium         Europe
# 13             Lithuania         Europe
# 14                 Japan           Asia
# 15               Iceland         Europe
# 16       Channel Islands         Europe
# 17               Denmark         Europe
# 18                Cyprus         Europe
# 19                Sweden         Europe
# 20               Austria         Europe
# 21                Israel           Asia
# 22               Finland         Europe
# 23               Bahrain           Asia
# 24                Greece         Europe
# 25             Hong Kong           Asia
# 26             Singapore           Asia
# 27               Lebanon           Asia
# 28  United Arab Emirates           Asia
# 29          Saudi Arabia           Asia
# 30        Czech Republic         Europe
# 31                Canada  North America
# 32           Unspecified        Unknown
# 33                Brazil  South America
# 34                   USA  North America
# 35    European Community         Europe
# 36                 Malta         Europe
# 37                   RSA         Africa

# %%
df_continent['Continent'].value_counts()
# Out:
# Europe           24
# Asia              8
# North America     2
# Oceania           1
# Unknown           1
# South America     1
# Africa            1
# Name: Continent, dtype: int64

# %%
df_continent['Continent'].count()
# Out:
# 38

# %% [markdown]
# # เช็คประเทศ

# %%
df_continent.sort_values(by = 'Continent')
# Out:
#                  Country      Continent
# 37                   RSA         Africa
# 14                 Japan           Asia
# 29          Saudi Arabia           Asia
# 28  United Arab Emirates           Asia
# 27               Lebanon           Asia
# 26             Singapore           Asia
# 25             Hong Kong           Asia
# 23               Bahrain           Asia
# 21                Israel           Asia
# 19                Sweden         Europe
# 20               Austria         Europe
# 24                Greece         Europe
# 36                 Malta         Europe
# 30        Czech Republic         Europe
# 35    European Community         Europe
# 22               Finland         Europe
# 17               Denmark         Europe
# 0         United Kingdom         Europe
# 15               Iceland         Europe
# 1                 France         Europe
# 3            Netherlands         Europe
# 4                Germany         Europe
# 16       Channel Islands         Europe
# 6                   EIRE         Europe
# 7            Switzerland         Europe
# 5                 Norway         Europe
# 9                 Poland         Europe
# 10              Portugal         Europe
# 11                 Italy         Europe
# 12               Belgium         Europe
# 13             Lithuania         Europe
# 8                  Spain         Europe
# 18                Cyprus         Europe
# 31                Canada  North America
# 34                   USA  North America
# 2              Australia        Oceania
# 33                Brazil  South America
# 32           Unspecified        Unknown

# %%
data_HW_continent = data_HW.merge(df_continent, how ='left', left_on='Country',right_on='Country')
print(data_HW_continent.shape)
data_HW_continent.head()
# Out:
# (541909, 9)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country Continent
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe

# %%
data_HW_continent
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
# [541909 rows x 9 columns]

# %%
data_HW_continent_date = data_HW_continent.copy()

# %%
data_HW_continent_date['date_time'] = pd.to_datetime(data_HW_continent_date['InvoiceDate'])

# %%
data_HW_continent_date.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
#
#             date_time
# 0 2010-12-01 08:26:00
# 1 2010-12-01 08:26:00
# 2 2010-12-01 08:26:00
# 3 2010-12-01 08:26:00
# 4 2010-12-01 08:26:00

# %%
data_HW_continent_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   Continent    541909 non-null  object
#  9   date_time    541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 45.5+ MB

# %% [markdown]
# # Data Prep

# %%
data.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
data[data['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/01/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/01/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/01/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/01/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/01/2010 14:34        0.0
# ...          ...       ...         ...       ...               ...        ...
# 535322    581199     84581         NaN        -2  12/07/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/07/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/07/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/08/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/08/2011 14:06        0.0
#
#         CustomerID         Country
# 622            NaN  United Kingdom
# 1970           NaN  United Kingdom
# 1971           NaN  United Kingdom
# 1972           NaN  United Kingdom
# 1987           NaN  United Kingdom
# ...            ...             ...
# 535322         NaN  United Kingdom
# 535326         NaN  United Kingdom
# 535332         NaN  United Kingdom
# 536981         NaN  United Kingdom
# 538554         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %%
len(set(data[data['Description'].isnull()]['StockCode']))
# Out:
# 960

# %%
data[data['StockCode'] == '22139']
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 106       536381     22139  RETROSPOT TEA SET CERAMIC 11 PC         23
# 622       536414     22139                               NaN        56
# 6392      536942     22139                            amazon        15
# 6885      536982     22139  RETROSPOT TEA SET CERAMIC 11 PC         10
# 7203      537011     22139                               NaN        -5
# ...          ...       ...                               ...       ...
# 538411    581405     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 539531    581439     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 540441    581486     22139  RETROSPOT TEA SET CERAMIC 11 PC          6
# 541387    581498     22139  RETROSPOT TEA SET CERAMIC 11 PC          2
# 541726    581570     22139  RETROSPOT TEA SET CERAMIC 11 PC          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 106     12/01/2010 09:41       4.25     15311.0  United Kingdom
# 622     12/01/2010 11:52       0.00         NaN  United Kingdom
# 6392    12/03/2010 12:08       0.00         NaN  United Kingdom
# 6885    12/03/2010 14:27      11.02         NaN  United Kingdom
# 7203    12/03/2010 15:38       0.00         NaN  United Kingdom
# ...                  ...        ...         ...             ...
# 538411  12/08/2011 13:50       4.95     13521.0  United Kingdom
# 539531  12/08/2011 16:30      10.79         NaN  United Kingdom
# 540441  12/09/2011 09:38       4.95     17001.0  United Kingdom
# 541387  12/09/2011 10:26      10.79         NaN  United Kingdom
# 541726  12/09/2011 11:59       4.95     12662.0         Germany
#
# [993 rows x 8 columns]

# %%
data[data['UnitPrice'] <0 ]
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  08/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  08/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
data.iloc[299980:299986]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 299980    563184    82494L        WOODEN FRAME ANTIQUE WHITE          4
# 299981    563184     82482  WOODEN PICTURE FRAME WHITE FINISH         4
# 299982   A563185         B                    Adjust bad debt         1
# 299983   A563186         B                    Adjust bad debt         1
# 299984   A563187         B                    Adjust bad debt         1
# 299985    563188     79160      HEART SHAPE WIRELESS DOORBELL        48
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 299980  08/12/2011 14:50       2.95     17516.0  United Kingdom
# 299981  08/12/2011 14:50       2.55     17516.0  United Kingdom
# 299982  08/12/2011 14:50   11062.06         NaN  United Kingdom
# 299983  08/12/2011 14:51  -11062.06         NaN  United Kingdom
# 299984  08/12/2011 14:52  -11062.06         NaN  United Kingdom
# 299985  08/12/2011 15:00       1.69     15606.0  United Kingdom

# %%
data[data['StockCode'] == 'B']
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1  08/12/2011 14:50
# 299983   A563186         B  Adjust bad debt         1  08/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  08/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
data[data['InvoiceNo'] == 'A563187' ]
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299984   A563187         B  Adjust bad debt         1  08/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299984  -11062.06         NaN  United Kingdom

# %%
data[data['Description'].isnull()]['StockCode'].value_counts()
# Out:
# 35965     10
# 23084     10
# 22084      9
# 22451      6
# 22501      5
#           ..
# 16169P     1
# 84846A     1
# 82545A     1
# 84251F     1
# 85175      1
# Name: StockCode, Length: 960, dtype: int64

# %%
data[data['Quantity']<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 141     12/01/2010 09:41      27.50     14527.0  United Kingdom
# 154     12/01/2010 09:49       4.65     15311.0  United Kingdom
# 235     12/01/2010 10:24       1.65     17548.0  United Kingdom
# 236     12/01/2010 10:24       0.29     17548.0  United Kingdom
# 237     12/01/2010 10:24       0.29     17548.0  United Kingdom
# ...                  ...        ...         ...             ...
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
# 541541  12/09/2011 10:28     224.69     15498.0  United Kingdom
# 541715  12/09/2011 11:57      10.95     15311.0  United Kingdom
# 541716  12/09/2011 11:58       1.25     17315.0  United Kingdom
# 541717  12/09/2011 11:58       1.25     17315.0  United Kingdom
#
# [10624 rows x 8 columns]

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
data_positive = data[(data['Quantity']>=0) & (data['UnitPrice'] >=0) ]
data_positive
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [531283 rows x 8 columns]

# %%
data_positive.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  531283.000000  531283.000000  397924.000000
# mean       10.655299       3.898954   15294.315171
# std       156.830617      35.876279    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %%
data_positive[data_positive['UnitPrice'] == 0]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 535334    581211     22142                         check        14
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/01/2010 11:52        0.0         NaN  United Kingdom
# 1970    12/01/2010 14:32        0.0         NaN  United Kingdom
# 1971    12/01/2010 14:33        0.0         NaN  United Kingdom
# 1972    12/01/2010 14:33        0.0         NaN  United Kingdom
# 1987    12/01/2010 14:34        0.0         NaN  United Kingdom
# ...                  ...        ...         ...             ...
# 535334  12/07/2011 18:36        0.0         NaN  United Kingdom
# 536981  12/08/2011 10:33        0.0         NaN  United Kingdom
# 538504  12/08/2011 13:58        0.0         NaN  United Kingdom
# 538505  12/08/2011 13:58        0.0         NaN  United Kingdom
# 538554  12/08/2011 14:06        0.0         NaN  United Kingdom
#
# [1179 rows x 8 columns]

# %%
data[(data['InvoiceNo'] == 'C581490') | (data['InvoiceNo'] == 'C581499')]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 540448   C581490     22178  VICTORIAN GLASS HANGING T-LIGHT       -12
# 540449   C581490     23144  ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                           Manual        -1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 540448  12/09/2011 09:57       1.95     14397.0  United Kingdom
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
# 541541  12/09/2011 10:28     224.69     15498.0  United Kingdom

# %%
data[(data['CustomerID'] == 14397)]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 182820    552575     22178    VICTORIAN GLASS HANGING T-LIGHT        24
# 182821    552575     23144    ZINC T-LIGHT HOLDER STARS SMALL        12
# 182822    552575     20846  ZINC HEART LATTICE T-LIGHT HOLDER        12
# 182823    552575     82484  WOOD BLACK BOARD ANT WHITE FINISH         2
# 182824    552575     84946       ANTIQUE SILVER T-LIGHT GLASS        12
# ...          ...       ...                                ...       ...
# 533101    581011     22478           BIRDHOUSE GARDEN MARKER         20
# 533102    581011     20846  ZINC HEART LATTICE T-LIGHT HOLDER        24
# 533103    581011     22600      CHRISTMAS RETROSPOT STAR WOOD        12
# 540448   C581490     22178    VICTORIAN GLASS HANGING T-LIGHT       -12
# 540449   C581490     23144    ZINC T-LIGHT HOLDER STARS SMALL       -11
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 182820  05/10/2011 12:25       1.25     14397.0  United Kingdom
# 182821  05/10/2011 12:25       0.83     14397.0  United Kingdom
# 182822  05/10/2011 12:25       1.25     14397.0  United Kingdom
# 182823  05/10/2011 12:25       7.95     14397.0  United Kingdom
# 182824  05/10/2011 12:25       1.25     14397.0  United Kingdom
# ...                  ...        ...         ...             ...
# 533101  12/07/2011 09:22       1.25     14397.0  United Kingdom
# 533102  12/07/2011 09:22       1.25     14397.0  United Kingdom
# 533103  12/07/2011 09:22       0.85     14397.0  United Kingdom
# 540448  12/09/2011 09:57       1.95     14397.0  United Kingdom
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
#
# [95 rows x 8 columns]

# %% [markdown]
# ## ตัดรายการที่มีค่า Quantity เป็น ลบ และ UnitPrice < 0

# %%
data_HW_continent_date_clean1 = data_HW_continent_date[(data_HW_continent_date['Quantity']>=0) & (data_HW_continent_date['UnitPrice'] >=0) ]
data_HW_continent_date_clean1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time
# 0      2010-12-01 08:26:00
# 1      2010-12-01 08:26:00
# 2      2010-12-01 08:26:00
# 3      2010-12-01 08:26:00
# 4      2010-12-01 08:26:00
# ...                    ...
# 541904 2011-12-09 12:50:00
# 541905 2011-12-09 12:50:00
# 541906 2011-12-09 12:50:00
# 541907 2011-12-09 12:50:00
# 541908 2011-12-09 12:50:00
#
# [531283 rows x 10 columns]

# %% [markdown]
# # Adding Time Period

# %%
data_dadate = data_HW_continent_date_clean1.copy()

# %%
data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time
# 0      2010-12-01 08:26:00
# 1      2010-12-01 08:26:00
# 2      2010-12-01 08:26:00
# 3      2010-12-01 08:26:00
# 4      2010-12-01 08:26:00
# ...                    ...
# 541904 2011-12-09 12:50:00
# 541905 2011-12-09 12:50:00
# 541906 2011-12-09 12:50:00
# 541907 2011-12-09 12:50:00
# 541908 2011-12-09 12:50:00
#
# [531283 rows x 10 columns]

# %% [markdown]
# ## period time

# %% [markdown]
# ## Christmas and New Year

# %%
# Christmas_period
# Define the date period
start_month = 12  # December
start_day = 1
end_month = 12    # December
end_day = 31

# Check if each date is within the specified period every year
data_dadate['Xmask_NY_Period'] = (
    (data_dadate['date_time'].dt.month > start_month) |
    ((data_dadate['date_time'].dt.month == start_month) & (data_dadate['date_time'].dt.day >= start_day))
) & (
    (data_dadate['date_time'].dt.month < end_month) |
    ((data_dadate['date_time'].dt.month == end_month) & (data_dadate['date_time'].dt.day <= end_day))
)

data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period
# 0      2010-12-01 08:26:00             True
# 1      2010-12-01 08:26:00             True
# 2      2010-12-01 08:26:00             True
# 3      2010-12-01 08:26:00             True
# 4      2010-12-01 08:26:00             True
# ...                    ...              ...
# 541904 2011-12-09 12:50:00             True
# 541905 2011-12-09 12:50:00             True
# 541906 2011-12-09 12:50:00             True
# 541907 2011-12-09 12:50:00             True
# 541908 2011-12-09 12:50:00             True
#
# [531283 rows x 11 columns]

# %%
data_dadate[data_dadate['Xmask_NY_Period']]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period
# 0      2010-12-01 08:26:00             True
# 1      2010-12-01 08:26:00             True
# 2      2010-12-01 08:26:00             True
# 3      2010-12-01 08:26:00             True
# 4      2010-12-01 08:26:00             True
# ...                    ...              ...
# 541904 2011-12-09 12:50:00             True
# 541905 2011-12-09 12:50:00             True
# 541906 2011-12-09 12:50:00             True
# 541907 2011-12-09 12:50:00             True
# 541908 2011-12-09 12:50:00             True
#
# [66818 rows x 11 columns]

# %% [markdown]
# ## Chinese New Year

# %%
# Chinese New Year
# Define the date period
start_month = 1  # January
start_day = 15
end_month = 2    # Febuary
end_day = 15

# Check if each date is within the specified period every year
data_dadate['CNY_Period'] = (
    (data_dadate['date_time'].dt.month > start_month) |
    ((data_dadate['date_time'].dt.month == start_month) & (data_dadate['date_time'].dt.day >= start_day))
) & (
    (data_dadate['date_time'].dt.month < end_month) |
    ((data_dadate['date_time'].dt.month == end_month) & (data_dadate['date_time'].dt.day <= end_day))
)

data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period
# 0      2010-12-01 08:26:00             True       False
# 1      2010-12-01 08:26:00             True       False
# 2      2010-12-01 08:26:00             True       False
# 3      2010-12-01 08:26:00             True       False
# 4      2010-12-01 08:26:00             True       False
# ...                    ...              ...         ...
# 541904 2011-12-09 12:50:00             True       False
# 541905 2011-12-09 12:50:00             True       False
# 541906 2011-12-09 12:50:00             True       False
# 541907 2011-12-09 12:50:00             True       False
# 541908 2011-12-09 12:50:00             True       False
#
# [531283 rows x 12 columns]

# %%
data_dadate[data_dadate['CNY_Period']]
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 58345    541238     21115                ROSE CARAVAN DOORSTOP         1
# 58346    541238     22957  SET 3 PAPER VINTAGE CHICK PAPER EGG         1
# 58347    541238     22758     LARGE PURPLE BABUSHKA NOTEBOOK           1
# 58348    541238     20750             RED RETROSPOT MINI CASES         2
# 58349    541238     22722    SET OF 6 SPICE TINS PANTRY DESIGN         1
# ...         ...       ...                                  ...       ...
# 91285    544089    15056N            EDWARDIAN PARASOL NATURAL         3
# 91286    544089    84406B       CREAM CUPID HEARTS COAT HANGER         3
# 91287    544089     22087             PAPER BUNTING WHITE LACE         3
# 91288    544089     22631             CIRCUS PARADE LUNCH BOX          2
# 91289    544089     22630                 DOLLY GIRL LUNCH BOX         2
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 58345  1/16/2011 10:42       6.75     16746.0  United Kingdom    Europe
# 58346  1/16/2011 10:42       2.95     16746.0  United Kingdom    Europe
# 58347  1/16/2011 10:42       1.25     16746.0  United Kingdom    Europe
# 58348  1/16/2011 10:42       7.95     16746.0  United Kingdom    Europe
# 58349  1/16/2011 10:42       3.95     16746.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 91285  2/15/2011 17:51       5.95         NaN  United Kingdom    Europe
# 91286  2/15/2011 17:51       4.15         NaN  United Kingdom    Europe
# 91287  2/15/2011 17:51       2.95         NaN  United Kingdom    Europe
# 91288  2/15/2011 17:51       1.95         NaN  United Kingdom    Europe
# 91289  2/15/2011 17:51       1.95         NaN  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period
# 58345 2011-01-16 10:42:00            False        True
# 58346 2011-01-16 10:42:00            False        True
# 58347 2011-01-16 10:42:00            False        True
# 58348 2011-01-16 10:42:00            False        True
# 58349 2011-01-16 10:42:00            False        True
# ...                   ...              ...         ...
# 91285 2011-02-15 17:51:00            False        True
# 91286 2011-02-15 17:51:00            False        True
# 91287 2011-02-15 17:51:00            False        True
# 91288 2011-02-15 17:51:00            False        True
# 91289 2011-02-15 17:51:00            False        True
#
# [32125 rows x 12 columns]

# %% [markdown]
# ##Valentine's Day

# %%
# Valentine's Day
# Define the date period
start_month = 2  # January
start_day = 14
end_month = 2    # Febuary
end_day = 14

# Check if each date is within the specified period every year
data_dadate['V_Period'] = (
    (data_dadate['date_time'].dt.month > start_month) |
    ((data_dadate['date_time'].dt.month == start_month) & (data_dadate['date_time'].dt.day >= start_day))
) & (
    (data_dadate['date_time'].dt.month < end_month) |
    ((data_dadate['date_time'].dt.month == end_month) & (data_dadate['date_time'].dt.day <= end_day))
)

data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
# [531283 rows x 13 columns]

# %%
data_dadate[data_dadate['V_Period']]
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 88847    543821     22926      IVORY GIANT GARDEN THERMOMETER         2
# 88848    543821     22928     YELLOW GIANT GARDEN THERMOMETER         2
# 88849    543821     22925       BLUE GIANT GARDEN THERMOMETER         2
# 88850    543821     85175               CACTI T-LIGHT CANDLES        16
# 88851    543821     22456     NATURAL SLATE CHALKBOARD LARGE          3
# ...         ...       ...                                 ...       ...
# 89949    543979     22196        SMALL HEART MEASURING SPOONS         1
# 89950    543979     21889              WOODEN BOX OF DOMINOES         1
# 89951    543979     85176          SEWING SUSAN 21 NEEDLE SET         1
# 89952    543979     37446  MINI CAKE STAND WITH HANGING CAKES         1
# 89953    543979     21657     MILK BOTTLE WITH GLASS STOPPER          1
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 88847   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88848   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88849   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88850   2/14/2011 9:24       0.42     17667.0  United Kingdom    Europe
# 88851   2/14/2011 9:24       4.95     17667.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 89949  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89950  2/14/2011 15:43       1.25     14606.0  United Kingdom    Europe
# 89951  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89952  2/14/2011 15:43       1.45     14606.0  United Kingdom    Europe
# 89953  2/14/2011 15:43       6.95     14606.0  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period
# 88847 2011-02-14 09:24:00            False        True      True
# 88848 2011-02-14 09:24:00            False        True      True
# 88849 2011-02-14 09:24:00            False        True      True
# 88850 2011-02-14 09:24:00            False        True      True
# 88851 2011-02-14 09:24:00            False        True      True
# ...                   ...              ...         ...       ...
# 89949 2011-02-14 15:43:00            False        True      True
# 89950 2011-02-14 15:43:00            False        True      True
# 89951 2011-02-14 15:43:00            False        True      True
# 89952 2011-02-14 15:43:00            False        True      True
# 89953 2011-02-14 15:43:00            False        True      True
#
# [1087 rows x 13 columns]

# %% [markdown]
# # Function gogo

# %%
def support(freqItem):
  return freqItem[1]

def item_description(stockCode, df):
  return set(df[(df['StockCode']==stockCode)]['Description'])

def find_stock(stockList):
  desDict = {}
  for stockCode in stockList:
    stockDes = set(data[(data['StockCode']==stockCode)]['Description'])
    print(stockCode + " : " + str(stockDes))
    desDict[stockCode] = stockDes
  return desDict


def printFrequentItemsets(freqItem, data, minCombo):
  for i in freqItem:
    if i[0].__len__()>=minCombo:
        print('-'*100)
        print(i[0])
        print('support: ' , i[1]*100)

        for j in i[0]:
          print(j)
          print(item_description(j, data))

        for k in i[2]:
          print('-'*30)
          print(k)
          print('-'*30)
        print('-' * 100)

# %%
stock_list = '20726', '22957', '22661', '22662', '20728', '22722', '22383'
ss = find_stock(stock_list)
# Out:
# 20726 : {'LUNCH BAG WOODLAND'}
# 22957 : {'SET 3 PAPER VINTAGE CHICK PAPER EGG'}
# 22661 : {'CHARLOTTE BAG DOLLY GIRL DESIGN'}
# 22662 : {'LUNCH BAG DOLLY GIRL DESIGN'}
# 20728 : {'LUNCH BAG CARS BLUE'}
# 22722 : {nan, 'SET OF 6 SPICE TINS PANTRY DESIGN'}
# 22383 : {'LUNCH BAG SUKI DESIGN ', 'LUNCH BAG SUKI  DESIGN '}

# %% [markdown]
# ##HW1 Q1 ของช่วงเวลา Christmas & New Year (1 Dec - 31 Dec)

# %%
data_XmaskNY = data_dadate[data_dadate['Xmask_NY_Period']]

# %%
data_XmaskNY.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
#
#             date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0 2010-12-01 08:26:00             True       False     False
# 1 2010-12-01 08:26:00             True       False     False
# 2 2010-12-01 08:26:00             True       False     False
# 3 2010-12-01 08:26:00             True       False     False
# 4 2010-12-01 08:26:00             True       False     False

# %%
transactions_xmas = data_XmaskNY.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.04
frequent_xmas = list(apriori(transactions_xmas,min_support = min_sup))
frequent_xmas.sort(reverse = True, key=support)

printFrequentItemsets(frequent_xmas, data_XmaskNY, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'22086', '22910'})
# support:  5.875202593192869
# 22086
# {"PAPER CHAIN KIT 50'S CHRISTMAS "}
# 22910
# {'PAPER CHAIN KIT VINTAGE CHRISTMAS'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.058752025931928686, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5197132616487455, lift=5.938205230319926)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6712962962962963, lift=5.938205230319926)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22835', '22112'})
# support:  4.4975688816855754
# 22835
# {'HOT WATER BOTTLE I AM SO POORLY'}
# 22112
# {'CHOCOLATE HOT WATER BOTTLE'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22835', '22112'}), confidence=0.044975688816855756, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22835'}), confidence=0.5162790697674419, lift=7.914141268236313)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22835'}), items_add=frozenset({'22112'}), confidence=0.6894409937888198, lift=7.914141268236313)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22727', '22726'})
# support:  4.4975688816855754
# 22727
# {'ALARM CLOCK BAKELIKE RED '}
# 22726
# {'ALARM CLOCK BAKELIKE GREEN'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22727', '22726'}), confidence=0.044975688816855756, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22727'}), confidence=0.7161290322580646, lift=12.10552364118427)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22726'}), confidence=0.7602739726027398, lift=12.105523641184268)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22111', '22112'})
# support:  4.051863857374392
# 22111
# {'SCOTTIE DOG HOT WATER BOTTLE'}
# 22112
# {'CHOCOLATE HOT WATER BOTTLE'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22111', '22112'}), confidence=0.04051863857374392, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22111'}), items_add=frozenset({'22112'}), confidence=0.45871559633027525, lift=5.265628333688927)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22111'}), confidence=0.46511627906976744, lift=5.265628333688927)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
set(data_XmaskNY[(data_XmaskNY['StockCode']=='22086')]['Description'])
# Out:
# {"PAPER CHAIN KIT 50'S CHRISTMAS "}

# %% [markdown]
# ## Q2 ของประเทศในทวีป Europe

# %%
data_eu = data_dadate[data_dadate['Continent'] == 'Europe']

# %%
data_eu.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
#
#             date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0 2010-12-01 08:26:00             True       False     False
# 1 2010-12-01 08:26:00             True       False     False
# 2 2010-12-01 08:26:00             True       False     False
# 3 2010-12-01 08:26:00             True       False     False
# 4 2010-12-01 08:26:00             True       False     False

# %%
transactions_eu = data_eu.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.035
frequent_eu = list(apriori(transactions_eu,min_support = min_sup))
frequent_eu.sort(reverse = True, key=support)

printFrequentItemsets(frequent_eu, data_eu, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'22386', '85099B'})
# support:  4.001942690626517
# 22386
# {'JUMBO BAG PINK POLKADOT'}
# 85099B
# {'JUMBO BAG RED RETROSPOT'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.04001942690626518, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6781893004115226, lift=6.700536322204054)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39539347408829173, lift=6.700536322204055)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22697', '22699'})
# support:  3.6862554638173872
# 22697
# {'GREEN REGENCY TEACUP AND SAUCER'}
# 22699
# {'ROSES REGENCY TEACUP AND SAUCER '}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22697', '22699'}), confidence=0.036862554638173874, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7544731610337974, lift=14.752708818315183)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7207977207977209, lift=14.752708818315183)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'21931', '85099B'})
# support:  3.516270033997086
# 21931
# {'JUMBO STORAGE BAG SUKI'}
# 85099B
# {'JUMBO BAG RED RETROSPOT'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21931', '85099B'}), confidence=0.03516270033997086, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21931'}), items_add=frozenset({'85099B'}), confidence=0.6125211505922167, lift=6.051732481139031)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'21931'}), confidence=0.3474088291746641, lift=6.05173248113903)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q3 ของช่วงเวลา ตรุษจีน ในทวีป Asia  (15 Jan - 15 Feb)

# %%
data_cny = data_dadate[(data_dadate['CNY_Period']) & (data_dadate['Continent'] == 'Asia')]

# %%
data_cny
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 69623    541975     22620          4 TRADITIONAL SPINNING TOPS        60
# 69624    541975    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA         6
# 69625    541975    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE         6
# 69626    541975     16236                 KITTY PENCIL ERASERS        28
# 69627    541975     21058               PARTY INVITES WOODLAND        12
# ...         ...       ...                                  ...       ...
# 89595    543911    47590B          PINK HAPPY BIRTHDAY BUNTING        12
# 89596    543911     22117     METAL SIGN HER DINNER IS SERVED         12
# 89597    543911     82567            AIRLINE LOUNGE,METAL SIGN        12
# 89598    543911     21910                  WAY OUT METAL SIGN         12
# 89599    543911     21911                   GARDEN METAL SIGN         12
#
#            InvoiceDate  UnitPrice  CustomerID               Country Continent  \
# 69623  1/24/2011 14:24       1.25         NaN             Hong Kong      Asia
# 69624  1/24/2011 14:24       3.75         NaN             Hong Kong      Asia
# 69625  1/24/2011 14:24       3.75         NaN             Hong Kong      Asia
# 69626  1/24/2011 14:24       0.21         NaN             Hong Kong      Asia
# 69627  1/24/2011 14:24       0.85         NaN             Hong Kong      Asia
# ...                ...        ...         ...                   ...       ...
# 89595  2/14/2011 12:46       5.45     17829.0  United Arab Emirates      Asia
# 89596  2/14/2011 12:46       2.95     17829.0  United Arab Emirates      Asia
# 89597  2/14/2011 12:46       2.10     17829.0  United Arab Emirates      Asia
# 89598  2/14/2011 12:46       1.65     17829.0  United Arab Emirates      Asia
# 89599  2/14/2011 12:46       1.65     17829.0  United Arab Emirates      Asia
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period
# 69623 2011-01-24 14:24:00            False        True     False
# 69624 2011-01-24 14:24:00            False        True     False
# 69625 2011-01-24 14:24:00            False        True     False
# 69626 2011-01-24 14:24:00            False        True     False
# 69627 2011-01-24 14:24:00            False        True     False
# ...                   ...              ...         ...       ...
# 89595 2011-02-14 12:46:00            False        True      True
# 89596 2011-02-14 12:46:00            False        True      True
# 89597 2011-02-14 12:46:00            False        True      True
# 89598 2011-02-14 12:46:00            False        True      True
# 89599 2011-02-14 12:46:00            False        True      True
#
# [273 rows x 13 columns]

# %%
transactions_cny = data_cny.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.25
frequentItemsets = list(apriori(transactions_cny,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>3:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'20682', '22202', '22551', '22203'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20682', '22202', '22551', '22203'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22551', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'20682', '22551', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'20682', '22202', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'20682', '22202', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20682', '22202'}), items_add=frozenset({'22551', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20682', '22203'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20682', '22551'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'20682', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'20682', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551', '22203'}), items_add=frozenset({'20682', '22202'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20682', '22202', '22203'}), items_add=frozenset({'22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20682', '22202', '22551'}), items_add=frozenset({'22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20682', '22551', '22203'}), items_add=frozenset({'22202'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22551', '22203'}), items_add=frozenset({'20682'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'82552', '21165', '82551', '85150'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82552', '21165', '82551', '85150'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'85150', '82552', '82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'21165', '82552', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'21165', '82551', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21165', '82552', '82551'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'21165', '82551'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'85150', '82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21165', '85150'}), items_add=frozenset({'82552', '82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552', '82551'}), items_add=frozenset({'21165', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '82551'}), items_add=frozenset({'21165', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'21165', '82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552', '21165', '82551'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'21165', '82551', '85150'}), items_add=frozenset({'82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21165', '82552', '85150'}), items_add=frozenset({'82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552', '85150', '82551'}), items_add=frozenset({'21165'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'21756', '22960', '85150', '22957'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21756', '22960', '85150', '22957'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'22957', '85150', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'21756', '85150', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'21756', '85150', '22957'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21756', '22960', '22957'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'21756', '22957'}), items_add=frozenset({'85150', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'22957', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21756', '85150'}), items_add=frozenset({'22957', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'21756', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957', '85150'}), items_add=frozenset({'21756', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'21756', '22957'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21756', '22960', '22957'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'21756', '85150', '22957'}), items_add=frozenset({'22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21756', '85150', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '85150', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=3.0)])

# %%
min_sup = 0.25
frequent_cny = list(apriori(transactions_cny,min_support = min_sup))
frequent_cny.sort(reverse = True, key=support)

printFrequentItemsets(frequent_cny, data_eu, 4)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'20682', '22202', '22551', '22203'})
# support:  33.33333333333333
# 20682
# {'RED RETROSPOT CHILDRENS UMBRELLA'}
# 22202
# {nan, 'MILK PAN PINK POLKADOT'}
# 22551
# {'PLASTERS IN TIN SPACEBOY'}
# 22203
# {'MILK PAN RED RETROSPOT'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20682', '22202', '22551', '22203'}), confidence=0.3333333333333333, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22551', '22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'20682', '22551', '22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'20682', '22202', '22551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'20682', '22202', '22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22202'}), items_add=frozenset({'22551', '22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22203'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22551'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'20682', '22551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'20682', '22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22551', '22203'}), items_add=frozenset({'20682', '22202'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22202', '22203'}), items_add=frozenset({'22551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22202', '22551'}), items_add=frozenset({'22203'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22551', '22203'}), items_add=frozenset({'22202'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202', '22551', '22203'}), items_add=frozenset({'20682'}), confidence=1.0, lift=3.0)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'82552', '21165', '82551', '85150'})
# support:  33.33333333333333
# 82552
# {'WASHROOM METAL SIGN'}
# 21165
# {'BEWARE OF THE CAT METAL SIGN '}
# 82551
# {'LAUNDRY 15C METAL SIGN'}
# 85150
# {nan, 'LADIES & GENTLEMEN METAL SIGN'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82552', '21165', '82551', '85150'}), confidence=0.3333333333333333, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'85150', '82552', '82551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'21165', '82552', '85150'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'21165', '82551', '85150'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21165', '82552', '82551'}), confidence=0.6666666666666666, lift=2.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82551'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'85150', '82551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '85150'}), items_add=frozenset({'82552', '82551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552', '82551'}), items_add=frozenset({'21165', '85150'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150', '82551'}), items_add=frozenset({'21165', '82552'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'21165', '82551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552', '21165', '82551'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82551', '85150'}), items_add=frozenset({'82552'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82552', '85150'}), items_add=frozenset({'82551'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552', '85150', '82551'}), items_add=frozenset({'21165'}), confidence=1.0, lift=3.0)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'21756', '22960', '85150', '22957'})
# support:  33.33333333333333
# 21756
# {'BATH BUILDING BLOCK WORD'}
# 22960
# {'JAM MAKING SET WITH JARS'}
# 85150
# {nan, 'LADIES & GENTLEMEN METAL SIGN'}
# 22957
# {'SET 3 PAPER VINTAGE CHICK PAPER EGG'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21756', '22960', '85150', '22957'}), confidence=0.3333333333333333, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'22957', '85150', '22960'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'21756', '85150', '22960'}), confidence=0.6666666666666666, lift=2.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'21756', '85150', '22957'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21756', '22960', '22957'}), confidence=0.6666666666666666, lift=2.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '22957'}), items_add=frozenset({'85150', '22960'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'22957', '85150'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '85150'}), items_add=frozenset({'22957', '22960'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'21756', '85150'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '85150'}), items_add=frozenset({'21756', '22960'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'21756', '22957'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '22960', '22957'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '85150', '22957'}), items_add=frozenset({'22960'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '85150', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '85150', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=3.0)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q4 ของช่วงเวลา  Christmas & New Year ในทวีป Europe (1 Dec - 31 Dec)

# %%
data_eu_xny = data_dadate[(data_dadate['Xmask_NY_Period']) & (data_dadate['Continent'] == 'Europe')]

# %%
data_eu_xny
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
# [66688 rows x 13 columns]

# %%
transactions_eu_xny = data_eu_xny.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.05
frequentItemsets = list(apriori(transactions_eu_xny, min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22086', '22910'}), support=0.05896705978039853, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.05896705978039853, lift=1.0), OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5197132616487454, lift=5.91655051108456), OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6712962962962963, lift=5.916550511084561)])

# %%
min_sup = 0.04
frequent_eu_xny = list(apriori(transactions_eu_xny,min_support = min_sup))
frequent_eu_xny.sort(reverse = True, key=support)

printFrequentItemsets(frequent_eu_xny, data_eu, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'22086', '22910'})
# support:  5.896705978039853
# 22086
# {"PAPER CHAIN KIT 50'S CHRISTMAS "}
# 22910
# {'PAPER CHAIN KIT VINTAGE CHRISTMAS'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.05896705978039853, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5197132616487454, lift=5.91655051108456)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6712962962962963, lift=5.916550511084561)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22835', '22112'})
# support:  4.5140300935339575
# 22835
# {'HOT WATER BOTTLE I AM SO POORLY'}
# 22112
# {'CHOCOLATE HOT WATER BOTTLE'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22835', '22112'}), confidence=0.04514030093533957, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22835'}), confidence=0.5162790697674419, lift=7.885280947566083)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22835'}), items_add=frozenset({'22112'}), confidence=0.6894409937888198, lift=7.885280947566084)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22727', '22726'})
# support:  4.473363155754371
# 22727
# {'ALARM CLOCK BAKELIKE RED '}
# 22726
# {nan, 'ALARM CLOCK BAKELIKE GREEN'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22727', '22726'}), confidence=0.044733631557543715, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22727'}), confidence=0.7142857142857143, lift=12.113300492610838)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22726'}), confidence=0.7586206896551724, lift=12.113300492610836)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22111', '22112'})
# support:  4.06669377795852
# 22111
# {'SCOTTIE DOG HOT WATER BOTTLE'}
# 22112
# {'CHOCOLATE HOT WATER BOTTLE'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22111', '22112'}), confidence=0.040666937779585195, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22111'}), items_add=frozenset({'22112'}), confidence=0.4587155963302752, lift=5.2464262854704495)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22111'}), confidence=0.46511627906976744, lift=5.2464262854704495)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q5 ของวันวาเลนไทน์

# %%
data_v = data_dadate[data_dadate['V_Period']]

# %%
data_v
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 88847    543821     22926      IVORY GIANT GARDEN THERMOMETER         2
# 88848    543821     22928     YELLOW GIANT GARDEN THERMOMETER         2
# 88849    543821     22925       BLUE GIANT GARDEN THERMOMETER         2
# 88850    543821     85175               CACTI T-LIGHT CANDLES        16
# 88851    543821     22456     NATURAL SLATE CHALKBOARD LARGE          3
# ...         ...       ...                                 ...       ...
# 89949    543979     22196        SMALL HEART MEASURING SPOONS         1
# 89950    543979     21889              WOODEN BOX OF DOMINOES         1
# 89951    543979     85176          SEWING SUSAN 21 NEEDLE SET         1
# 89952    543979     37446  MINI CAKE STAND WITH HANGING CAKES         1
# 89953    543979     21657     MILK BOTTLE WITH GLASS STOPPER          1
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 88847   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88848   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88849   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88850   2/14/2011 9:24       0.42     17667.0  United Kingdom    Europe
# 88851   2/14/2011 9:24       4.95     17667.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 89949  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89950  2/14/2011 15:43       1.25     14606.0  United Kingdom    Europe
# 89951  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89952  2/14/2011 15:43       1.45     14606.0  United Kingdom    Europe
# 89953  2/14/2011 15:43       6.95     14606.0  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period
# 88847 2011-02-14 09:24:00            False        True      True
# 88848 2011-02-14 09:24:00            False        True      True
# 88849 2011-02-14 09:24:00            False        True      True
# 88850 2011-02-14 09:24:00            False        True      True
# 88851 2011-02-14 09:24:00            False        True      True
# ...                   ...              ...         ...       ...
# 89949 2011-02-14 15:43:00            False        True      True
# 89950 2011-02-14 15:43:00            False        True      True
# 89951 2011-02-14 15:43:00            False        True      True
# 89952 2011-02-14 15:43:00            False        True      True
# 89953 2011-02-14 15:43:00            False        True      True
#
# [1087 rows x 13 columns]

# %%
data_v['Country'].unique()
# Out:
# array(['United Kingdom', 'Spain', 'EIRE', 'Germany',
#        'United Arab Emirates'], dtype=object)

# %%
transactions_v = data_v.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
transactions_v
# Out:
# InvoiceNo
# 543821    [22926, 22928, 22925, 85175, 22456, 22854, 227...
# 543822    [22139, 20973, 22585, 22960, 84380, 84378, 229...
# 543823                         [22138, 21658, 22567, 20914]
# 543824    [22745, 22746, 20971, 20972, 16225, 22748, 227...
# 543825    [22926, 22782, 22411, 20914, 22381, 20681, 22690]
# 543826    [90104, 90146, 90175A, 90181B, 90214J, 90214S,...
# 543828    [22723, 22722, 22720, 22899, 22567, 84987, 228...
# 543829    [21238, 21239, 21240, 84997B, 84997D, 84997C, ...
# 543831    [84519A, 20711, 20713, 85099F, 22385, 21929, 2...
# 543832    [84879, 22077, 22855, 21899, 21900, 21901, 219...
# 543833    [22788, 22957, 21621, 22722, 22384, 21791, 217...
# 543836    [84987, 84991, 84988, 84992, 84378, 22965, 229...
# 543839                               [22207, 21731, 47590A]
# 543842                                              [22693]
# 543852    [22355, 21931, 22356, 85123A, 85175, 82484, 82...
# 543899    [C2, 21340, 21792, 22503, 15056N, 22630, 22983...
# 543900    [22355, 20719, 20723, 17003, 22331, 22385, 845...
# 543901           [21257, 22509, 22968, 20969, 22447, 22587]
# 543907    [84879, 22374, 22470, 22195, 22383, 47578A, 84...
# 543908                               [47590B, 21380, 22090]
# 543909    [16238, 20751, 21912, 21914, 21915, 21935, 219...
# 543910    [84978, 22595, 22197, 22469, 22470, 21523, 226...
# 543911    [21485, 48138, 85150, 82552, 82551, 82583, 224...
# 543912                  [21527, 21524, 20750, 21868, 37370]
# 543913    [21832, 82583, 21175, 21174, 21166, 82600, 825...
# 543914    [84356, 21221, 21681, 21682, 16237, 22491, 207...
# 543915    [10135, 47504K, 84509G, 84817, 84826, 85034C, ...
# 543916    [21034, 85099B, 22411, 85099C, 22386, 21928, 2...
# 543919    [20728, 84077, 22147, 22383, 22382, 20727, 227...
# 543920                                              [22171]
# 543921    [21613, 85173, 85206A, 22021, 21454, 22286, 35...
# 543922                                             [47570B]
# 543923    [22933, 22937, 22930, 22931, 22934, 22697, 226...
# 543924    [20785, 82551, 21380, 21175, 21174, 21179, 219...
# 543934    [21790, 22380, 22381, 22858, 21156, 21935, 227...
# 543935    [22607, 22605, 22698, 22301, 21621, 21137, 22041]
# 543973    [84755, 21688, 85062, 21695, 20668, 21340, 214...
# 543975    [84406B, 22926, 21870, 21874, 21713, 21714, 22...
# 543976                         [84879, 22423, 21422, 21421]
# 543977    [22384, 21211, 21210, 82551, 22457, 21623, 207...
# 543978    [22985, 22045, 23233, 23232, 23231, 85175, 223...
# 543979    [22072, 84988, 22382, 21931, 22380, 72760B, 22...
# Name: StockCode, dtype: object

# %%
len(transactions_v)
# Out:
# 42

# %%
min_sup = 0.1
frequentItemsets = list(apriori(transactions_v,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22720', '22722'}), support=0.11904761904761904, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22722'}), confidence=0.11904761904761904, lift=1.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22722'}), confidence=0.7142857142857143, lift=5.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22720'}), confidence=0.8333333333333334, lift=5.000000000000001)])
# yes
# RelationRecord(items=frozenset({'22720', '22969'}), support=0.11904761904761904, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22969'}), confidence=0.11904761904761904, lift=1.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22969'}), confidence=0.7142857142857143, lift=6.000000000000001), OrderedStatistic(items_base=frozenset({'22969'}), items_add=frozenset({'22720'}), confidence=1.0, lift=6.0)])

# %%
min_sup = 0.1
frequent_v = list(apriori(transactions_v,min_support = min_sup))
frequent_v.sort(reverse = True, key=support)

printFrequentItemsets(frequent_v, data_v, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'22720', '22722'})
# support:  11.904761904761903
# 22720
# {'SET OF 3 CAKE TINS PANTRY DESIGN '}
# 22722
# {'SET OF 6 SPICE TINS PANTRY DESIGN'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22722'}), confidence=0.11904761904761904, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22722'}), confidence=0.7142857142857143, lift=5.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22720'}), confidence=0.8333333333333334, lift=5.000000000000001)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22720', '22969'})
# support:  11.904761904761903
# 22720
# {'SET OF 3 CAKE TINS PANTRY DESIGN '}
# 22969
# {'HOMEMADE JAM SCENTED CANDLES'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22969'}), confidence=0.11904761904761904, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22969'}), confidence=0.7142857142857143, lift=6.000000000000001)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22969'}), items_add=frozenset({'22720'}), confidence=1.0, lift=6.0)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q6 โดยจัดกลุ่มตามประเทศ + เดือน

# %%
data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
# [531283 rows x 13 columns]

# %%
data_q6 = data_dadate.copy()

# %%
data_q6[['InvoiceDate1', 'InvoiceTime']] = (data_q6['InvoiceDate'].str.split(' ', n=1, expand = True))
data_q6
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period  \
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
#        InvoiceDate1 InvoiceTime
# 0        12/01/2010       08:26
# 1        12/01/2010       08:26
# 2        12/01/2010       08:26
# 3        12/01/2010       08:26
# 4        12/01/2010       08:26
# ...             ...         ...
# 541904   12/09/2011       12:50
# 541905   12/09/2011       12:50
# 541906   12/09/2011       12:50
# 541907   12/09/2011       12:50
# 541908   12/09/2011       12:50
#
# [531283 rows x 15 columns]

# %%
data_q6[['month', 'day', 'year']] = (data_q6['InvoiceDate1'].str.split('/', n=2, expand = True))

# %%
data_q6
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period  \
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
#        InvoiceDate1 InvoiceTime month day  year
# 0        12/01/2010       08:26    12  01  2010
# 1        12/01/2010       08:26    12  01  2010
# 2        12/01/2010       08:26    12  01  2010
# 3        12/01/2010       08:26    12  01  2010
# 4        12/01/2010       08:26    12  01  2010
# ...             ...         ...   ...  ..   ...
# 541904   12/09/2011       12:50    12  09  2011
# 541905   12/09/2011       12:50    12  09  2011
# 541906   12/09/2011       12:50    12  09  2011
# 541907   12/09/2011       12:50    12  09  2011
# 541908   12/09/2011       12:50    12  09  2011
#
# [531283 rows x 18 columns]

# %%
data_q6['month'].unique()
# Out:
# array(['12', '01', '1', '02', '2', '03', '3', '04', '4', '05', '5', '06',
#        '6', '07', '7', '08', '8', '09', '9', '10', '11'], dtype=object)

# %%
data_q6['InvoiceDate1'].value_counts()
# Out:
# 12/05/2011    5302
# 12/08/2011    4871
# 11/29/2011    4295
# 11/16/2011    4150
# 11/11/2011    4071
#               ...
# 08/07/2011     529
# 12/19/2010     518
# 05/01/2011     448
# 12/22/2010     286
# 02/06/2011     279
# Name: InvoiceDate1, Length: 305, dtype: int64

# %%
transactions_q6 = data_q6.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_q6
# Out:
# Country      month
# Australia    01       [22078, 22079, 22080, 22077, 22505, 22516, 225...
#              02       [84978, 22960, 47590B, 47566, 22087, 22720, 22...
#              03       [22978, 22980, 22993, 22654, 22968, 22505, 225...
#              04       [POST, 22993, 22449, 20726, 20725, 20727, 2238...
#              05       [22699, 22859, 22730, 84663A, 23206, 48129, 23...
#                                             ...
# Unspecified  11       [22326, 20725, 22628, 22631, 84997D, 23254, 23...
#              5        [23090, 47021G, 79030D, 84877A, 22178, 84913B,...
#              6        [23122, 23119, 23108, 23240, 23237, 23239, 232...
#              7        [22960, 16161P, 21499, 21500, 21503, 22047, 22...
#              8        [23236, 21210, 23313, 23318, 22952, 22950, 232...
# Name: StockCode, Length: 401, dtype: object

# %%
min_sup = 0.25
frequentItemsets = list(apriori(transactions_q6,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22326', '22328'}), support=0.256857855361596, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22326', '22328'}), confidence=0.256857855361596, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'22328'}), confidence=0.7006802721088435, lift=2.4014768300482587), OrderedStatistic(items_base=frozenset({'22328'}), items_add=frozenset({'22326'}), confidence=0.8803418803418803, lift=2.4014768300482587)])
# yes
# RelationRecord(items=frozenset({'22326', '22629'}), support=0.26433915211970077, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22326', '22629'}), confidence=0.26433915211970077, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'22629'}), confidence=0.7210884353741498, lift=2.1741087412408575), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'22326'}), confidence=0.7969924812030076, lift=2.1741087412408575)])
# yes
# RelationRecord(items=frozenset({'POST', '22326'}), support=0.29925187032418954, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22326'}), confidence=0.29925187032418954, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'POST'}), confidence=0.816326530612245, lift=1.417086315045499), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22326'}), confidence=0.5194805194805195, lift=1.4170863150454989)])
# yes
# RelationRecord(items=frozenset({'POST', '22423'}), support=0.2718204488778055, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22423'}), confidence=0.2718204488778055, lift=1.0), OrderedStatistic(items_base=frozenset({'22423'}), items_add=frozenset({'POST'}), confidence=0.6566265060240964, lift=1.1398581338340377), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22423'}), confidence=0.47186147186147187, lift=1.1398581338340374)])
# yes
# RelationRecord(items=frozenset({'22554', 'POST'}), support=0.26433915211970077, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22554', 'POST'}), confidence=0.26433915211970077, lift=1.0), OrderedStatistic(items_base=frozenset({'22554'}), items_add=frozenset({'POST'}), confidence=0.8346456692913387, lift=1.4488870709343151), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22554'}), confidence=0.45887445887445893, lift=1.4488870709343153)])
# yes
# RelationRecord(items=frozenset({'POST', '22556'}), support=0.26433915211970077, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22556'}), confidence=0.26433915211970077, lift=1.0), OrderedStatistic(items_base=frozenset({'22556'}), items_add=frozenset({'POST'}), confidence=0.8153846153846154, lift=1.4154512154512155), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22556'}), confidence=0.45887445887445893, lift=1.4154512154512155)])
# yes
# RelationRecord(items=frozenset({'22630', '22629'}), support=0.27680798004987534, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22630', '22629'}), confidence=0.27680798004987534, lift=1.0), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'22630'}), confidence=0.8345864661654137, lift=2.6351903380498496), OrderedStatistic(items_base=frozenset({'22630'}), items_add=frozenset({'22629'}), confidence=0.8740157480314962, lift=2.6351903380498496)])
# yes
# RelationRecord(items=frozenset({'POST', '22629'}), support=0.256857855361596, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22629'}), confidence=0.256857855361596, lift=1.0), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'POST'}), confidence=0.7744360902255639, lift=1.344367412036585), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22629'}), confidence=0.4458874458874459, lift=1.344367412036585)])

# %%
min_sup = 0.25
frequent_q6 = list(apriori(transactions_q6,min_support = min_sup))
frequent_q6.sort(reverse = True, key=support)

printFrequentItemsets(frequent_q6, data_v, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'POST', '22326'})
# support:  29.925187032418954
# POST
# {'POSTAGE'}
# 22326
# {'ROUND SNACK BOXES SET OF4 WOODLAND '}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22326'}), confidence=0.29925187032418954, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'POST'}), confidence=0.816326530612245, lift=1.417086315045499)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22326'}), confidence=0.5194805194805195, lift=1.4170863150454989)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22630', '22629'})
# support:  27.680798004987533
# 22630
# {'DOLLY GIRL LUNCH BOX'}
# 22629
# set()
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22630', '22629'}), confidence=0.27680798004987534, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'22630'}), confidence=0.8345864661654137, lift=2.6351903380498496)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22630'}), items_add=frozenset({'22629'}), confidence=0.8740157480314962, lift=2.6351903380498496)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'POST', '22423'})
# support:  27.18204488778055
# POST
# {'POSTAGE'}
# 22423
# {'REGENCY CAKESTAND 3 TIER'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22423'}), confidence=0.2718204488778055, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22423'}), items_add=frozenset({'POST'}), confidence=0.6566265060240964, lift=1.1398581338340377)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22423'}), confidence=0.47186147186147187, lift=1.1398581338340374)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22326', '22629'})
# support:  26.433915211970078
# 22326
# {'ROUND SNACK BOXES SET OF4 WOODLAND '}
# 22629
# set()
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22326', '22629'}), confidence=0.26433915211970077, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'22629'}), confidence=0.7210884353741498, lift=2.1741087412408575)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'22326'}), confidence=0.7969924812030076, lift=2.1741087412408575)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22554', 'POST'})
# support:  26.433915211970078
# 22554
# {'PLASTERS IN TIN WOODLAND ANIMALS'}
# POST
# {'POSTAGE'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22554', 'POST'}), confidence=0.26433915211970077, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22554'}), items_add=frozenset({'POST'}), confidence=0.8346456692913387, lift=1.4488870709343151)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22554'}), confidence=0.45887445887445893, lift=1.4488870709343153)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'POST', '22556'})
# support:  26.433915211970078
# POST
# {'POSTAGE'}
# 22556
# set()
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22556'}), confidence=0.26433915211970077, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22556'}), items_add=frozenset({'POST'}), confidence=0.8153846153846154, lift=1.4154512154512155)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22556'}), confidence=0.45887445887445893, lift=1.4154512154512155)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22326', '22328'})
# support:  25.6857855361596
# 22326
# {'ROUND SNACK BOXES SET OF4 WOODLAND '}
# 22328
# set()
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22326', '22328'}), confidence=0.256857855361596, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'22328'}), confidence=0.7006802721088435, lift=2.4014768300482587)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22328'}), items_add=frozenset({'22326'}), confidence=0.8803418803418803, lift=2.4014768300482587)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'POST', '22629'})
# support:  25.6857855361596
# POST
# {'POSTAGE'}
# 22629
# set()
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22629'}), confidence=0.256857855361596, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'POST'}), confidence=0.7744360902255639, lift=1.344367412036585)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22629'}), confidence=0.4458874458874459, lift=1.344367412036585)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Q6 - Q1 ของช่วงเวลา Christmas & New Year (1 Dec - 31 Dec)

# %%
data_q6_XmaskNY = data_q6[data_q6['Xmask_NY_Period']]

# %%
data_q6_XmaskNY
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010       3.39     17850.0  United Kingdom    Europe
# ...            ...        ...         ...             ...       ...
# 541904  12/09/2011       0.85     12680.0          France    Europe
# 541905  12/09/2011       2.10     12680.0          France    Europe
# 541906  12/09/2011       4.15     12680.0          France    Europe
# 541907  12/09/2011       4.15     12680.0          France    Europe
# 541908  12/09/2011       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period InvoiceTime  \
# 0      2010-12-01 08:26:00             True       False     False       08:26
# 1      2010-12-01 08:26:00             True       False     False       08:26
# 2      2010-12-01 08:26:00             True       False     False       08:26
# 3      2010-12-01 08:26:00             True       False     False       08:26
# 4      2010-12-01 08:26:00             True       False     False       08:26
# ...                    ...              ...         ...       ...         ...
# 541904 2011-12-09 12:50:00             True       False     False       12:50
# 541905 2011-12-09 12:50:00             True       False     False       12:50
# 541906 2011-12-09 12:50:00             True       False     False       12:50
# 541907 2011-12-09 12:50:00             True       False     False       12:50
# 541908 2011-12-09 12:50:00             True       False     False       12:50
#
#        month day  year
# 0         12  01  2010
# 1         12  01  2010
# 2         12  01  2010
# 3         12  01  2010
# 4         12  01  2010
# ...      ...  ..   ...
# 541904    12  09  2011
# 541905    12  09  2011
# 541906    12  09  2011
# 541907    12  09  2011
# 541908    12  09  2011
#
# [66818 rows x 17 columns]

# %%
data_q6_XmaskNY['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'USA', 'Greece'], dtype=object)

# %%
data_q6
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010       3.39     17850.0  United Kingdom    Europe
# ...            ...        ...         ...             ...       ...
# 541904  12/09/2011       0.85     12680.0          France    Europe
# 541905  12/09/2011       2.10     12680.0          France    Europe
# 541906  12/09/2011       4.15     12680.0          France    Europe
# 541907  12/09/2011       4.15     12680.0          France    Europe
# 541908  12/09/2011       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period InvoiceTime  \
# 0      2010-12-01 08:26:00             True       False     False       08:26
# 1      2010-12-01 08:26:00             True       False     False       08:26
# 2      2010-12-01 08:26:00             True       False     False       08:26
# 3      2010-12-01 08:26:00             True       False     False       08:26
# 4      2010-12-01 08:26:00             True       False     False       08:26
# ...                    ...              ...         ...       ...         ...
# 541904 2011-12-09 12:50:00             True       False     False       12:50
# 541905 2011-12-09 12:50:00             True       False     False       12:50
# 541906 2011-12-09 12:50:00             True       False     False       12:50
# 541907 2011-12-09 12:50:00             True       False     False       12:50
# 541908 2011-12-09 12:50:00             True       False     False       12:50
#
#        month day  year
# 0         12  01  2010
# 1         12  01  2010
# 2         12  01  2010
# 3         12  01  2010
# 4         12  01  2010
# ...      ...  ..   ...
# 541904    12  09  2011
# 541905    12  09  2011
# 541906    12  09  2011
# 541907    12  09  2011
# 541908    12  09  2011
#
# [531283 rows x 17 columns]

# %%
transactions_q6_xmas = data_q6_XmaskNY.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_q6_xmas
# Out:
# Country          month
# Australia        12       [22941, 21622, 21791, 35004C, 35004G, 85014B, ...
# Austria          12       [37449, 37446, 22962, 21428, 22113, 22313, 223...
# Bahrain          12                                                [72802B]
# Belgium          12       [84375, 21217, 21212, 21977, 22417, 21975, 219...
# Channel Islands  12       [22690, 21955, 20685, 21523, 21169, 22112, 214...
# Cyprus           12       [85123A, 21031, 21026, 21025, 21032, 21030, 21...
# Denmark          12       [22847, 22779, 22331, 22365, 22673, 22670, 825...
# EIRE             12       [22968, 85071A, 85071C, 22355, 21579, 21576, 2...
# Finland          12       [84992, 22951, 84991, 84991, 21213, 21213, 226...
# France           12       [22728, 22727, 22726, 21724, 21883, 10002, 217...
# Germany          12       [22809, 84347, 84945, 22242, 22244, 22243, 474...
# Greece           12       [POST, 20685, 22941, 22816, 22966, 20725, 2072...
# Iceland          12       [85116, 22375, 71477, 22492, 22771, 22772, 227...
# Italy            12       [22791, 21287, 79337, 85111, 85038, 22809, 228...
# Japan            12       [85016, 21506, 22716, 22983, 22030, 22984, 850...
# Lithuania        12       [22409, 21915, 15056BL, 15056N, 20679, 20686, ...
# Netherlands      12       [22867, POST, 21981, 21986, 22720, 21931, 2261...
# Norway           12       [84692, 22444, 22899, 21156, 22556, 22555, 225...
# Poland           12       [21733, 21232, 37446, 37448, 21700, 22844, 229...
# Portugal         12       [21992, 22383, 20728, 20658, 20669, POST, 2072...
# Spain            12       [22383, 22384, 20727, 20725, 20728, 22504, 222...
# Sweden           12       [85232B, 84077, 22951, 22417, 21977, 84992, 21...
# Switzerland      12       [22326, 22554, 21731, 20677, 20750, POST, 2283...
# USA              12       [22712, 23344, 85099B, 23209, 79191C, 23392, 8...
# United Kingdom   12       [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# Name: StockCode, dtype: object

# %%
transactions_q6_xmas[1]
# Out:
# ['37449',
#  '37446',
#  '22962',
#  '21428',
#  '22113',
#  '22313',
#  '22312',
#  'POST',
#  '20679',
#  '15056N',
#  '15056BL',
#  '15056P',
#  '22059',
#  '22646',
#  'POST']

# %%
min_sup = 0.3
frequentItemsets = list(apriori(transactions_q6_xmas,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'POST', '20750'}), support=0.36, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '20750'}), confidence=0.36, lift=1.0), OrderedStatistic(items_base=frozenset({'20750'}), items_add=frozenset({'POST'}), confidence=0.8999999999999999, lift=1.6071428571428568), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'20750'}), confidence=0.6428571428571428, lift=1.607142857142857)])
# yes
# RelationRecord(items=frozenset({'POST', '22326'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22326'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'POST'}), confidence=0.888888888888889, lift=1.5873015873015872), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22326'}), confidence=0.5714285714285714, lift=1.5873015873015872)])
# yes
# RelationRecord(items=frozenset({'POST', '22423'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22423'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'22423'}), items_add=frozenset({'POST'}), confidence=0.888888888888889, lift=1.5873015873015872), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22423'}), confidence=0.5714285714285714, lift=1.5873015873015872)])
# yes
# RelationRecord(items=frozenset({'POST', '22629'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22629'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'POST'}), confidence=1.0, lift=1.7857142857142856), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22629'}), confidence=0.5714285714285714, lift=1.7857142857142856)])
# yes
# RelationRecord(items=frozenset({'22727', '22726'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22727', '22726'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22727'}), confidence=0.888888888888889, lift=2.469135802469136), OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22726'}), confidence=0.888888888888889, lift=2.469135802469136)])
# yes
# RelationRecord(items=frozenset({'22728', '22726'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22728', '22726'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22728'}), confidence=0.888888888888889, lift=2.469135802469136), OrderedStatistic(items_base=frozenset({'22728'}), items_add=frozenset({'22726'}), confidence=0.888888888888889, lift=2.469135802469136)])
# yes
# RelationRecord(items=frozenset({'22727', '22728'}), support=0.36, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22727', '22728'}), confidence=0.36, lift=1.0), OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22728'}), confidence=1.0, lift=2.7777777777777777), OrderedStatistic(items_base=frozenset({'22728'}), items_add=frozenset({'22727'}), confidence=1.0, lift=2.7777777777777777)])
# yes
# RelationRecord(items=frozenset({'POST', '23084'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '23084'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'23084'}), items_add=frozenset({'POST'}), confidence=0.888888888888889, lift=1.5873015873015872), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'23084'}), confidence=0.5714285714285714, lift=1.5873015873015872)])
# yes
# RelationRecord(items=frozenset({'22727', '22728', '22726'}), support=0.32, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22727', '22728', '22726'}), confidence=0.32, lift=1.0), OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22727', '22728'}), confidence=0.888888888888889, lift=2.469135802469136), OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22728', '22726'}), confidence=0.888888888888889, lift=2.777777777777778), OrderedStatistic(items_base=frozenset({'22728'}), items_add=frozenset({'22727', '22726'}), confidence=0.888888888888889, lift=2.777777777777778), OrderedStatistic(items_base=frozenset({'22727', '22726'}), items_add=frozenset({'22728'}), confidence=1.0, lift=2.7777777777777777), OrderedStatistic(items_base=frozenset({'22728', '22726'}), items_add=frozenset({'22727'}), confidence=1.0, lift=2.7777777777777777), OrderedStatistic(items_base=frozenset({'22727', '22728'}), items_add=frozenset({'22726'}), confidence=0.888888888888889, lift=2.469135802469136)])

# %%
min_sup = 0.35
frequent_q6_xmas = list(apriori(transactions_q6_xmas,min_support = min_sup))
frequent_q6_xmas.sort(reverse = True, key=support)

printFrequentItemsets(frequent_q6_xmas, data_q6_XmaskNY, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'POST', '20750'})
# support:  36.0
# POST
# {'POSTAGE'}
# 20750
# {'RED RETROSPOT MINI CASES'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '20750'}), confidence=0.36, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20750'}), items_add=frozenset({'POST'}), confidence=0.8999999999999999, lift=1.6071428571428568)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'20750'}), confidence=0.6428571428571428, lift=1.607142857142857)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'22727', '22728'})
# support:  36.0
# 22727
# {'ALARM CLOCK BAKELIKE RED '}
# 22728
# {'ALARM CLOCK BAKELIKE PINK'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22727', '22728'}), confidence=0.36, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22728'}), confidence=1.0, lift=2.7777777777777777)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22728'}), items_add=frozenset({'22727'}), confidence=1.0, lift=2.7777777777777777)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Q6-Q2 ของประเทศในทวีป Europe

# %%
data_q6_eu = data_q6[data_q6['Continent'] == 'Europe']

# %%
data_q6_eu
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010       3.39     17850.0  United Kingdom    Europe
# ...            ...        ...         ...             ...       ...
# 541904  12/09/2011       0.85     12680.0          France    Europe
# 541905  12/09/2011       2.10     12680.0          France    Europe
# 541906  12/09/2011       4.15     12680.0          France    Europe
# 541907  12/09/2011       4.15     12680.0          France    Europe
# 541908  12/09/2011       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period InvoiceTime  \
# 0      2010-12-01 08:26:00             True       False     False       08:26
# 1      2010-12-01 08:26:00             True       False     False       08:26
# 2      2010-12-01 08:26:00             True       False     False       08:26
# 3      2010-12-01 08:26:00             True       False     False       08:26
# 4      2010-12-01 08:26:00             True       False     False       08:26
# ...                    ...              ...         ...       ...         ...
# 541904 2011-12-09 12:50:00             True       False     False       12:50
# 541905 2011-12-09 12:50:00             True       False     False       12:50
# 541906 2011-12-09 12:50:00             True       False     False       12:50
# 541907 2011-12-09 12:50:00             True       False     False       12:50
# 541908 2011-12-09 12:50:00             True       False     False       12:50
#
#        month day  year
# 0         12  01  2010
# 1         12  01  2010
# 2         12  01  2010
# 3         12  01  2010
# 4         12  01  2010
# ...      ...  ..   ...
# 541904    12  09  2011
# 541905    12  09  2011
# 541906    12  09  2011
# 541907    12  09  2011
# 541908    12  09  2011
#
# [527970 rows x 17 columns]

# %%
transactions_q6_eu = data_q6_eu.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_q6_eu
# Out:
# Country         month
# Austria         02       [20713, 21931, 22553, 20724, 20719, 20726, 223...
#                 03                             [22556, 22139, 84879, POST]
#                 05             [47566, 47590B, 47590A, 21172, 21207, POST]
#                 07       [15060B, 22059, 37449, 37447, 48185, 15056P, 1...
#                 08       [23293, 22844, 22845, 22712, 22029, 22814, 226...
#                                                ...
# United Kingdom  5        [22561, 22491, 22522, 22523, 22520, 22524, 101...
#                 6        [22776, 23170, 23174, 23175, 23093, 22179, 232...
#                 7        [21314, 21447, 22487, 85066, 22826, 22697, 226...
#                 8        [22457, 22456, 85123A, 22189, 22156, 75049L, 2...
#                 9        [23084, 23198, 22993, 23171, 23170, 23173, 231...
# Name: StockCode, Length: 324, dtype: object

# %%
transactions_q6_eu[1]
# Out:
# ['22556', '22139', '84879', 'POST']

# %%
min_sup = 0.3
frequentItemsets = list(apriori(transactions_q6_eu,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'POST', '21212'}), support=0.30864197530864196, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '21212'}), confidence=0.30864197530864196, lift=1.0), OrderedStatistic(items_base=frozenset({'21212'}), items_add=frozenset({'POST'}), confidence=0.7692307692307692, lift=1.102791014295439), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'21212'}), confidence=0.44247787610619466, lift=1.102791014295439)])
# yes
# RelationRecord(items=frozenset({'22326', '22328'}), support=0.3117283950617284, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22326', '22328'}), confidence=0.3117283950617284, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'22328'}), confidence=0.7481481481481481, lift=2.164285714285714), OrderedStatistic(items_base=frozenset({'22328'}), items_add=frozenset({'22326'}), confidence=0.9017857142857143, lift=2.164285714285714)])
# yes
# RelationRecord(items=frozenset({'22326', '22629'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22326', '22629'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'22629'}), confidence=0.7333333333333334, lift=1.9636363636363638), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'22326'}), confidence=0.8181818181818182, lift=1.9636363636363636)])
# yes
# RelationRecord(items=frozenset({'POST', '22326'}), support=0.36728395061728397, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22326'}), confidence=0.36728395061728397, lift=1.0), OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'POST'}), confidence=0.8814814814814815, lift=1.263716814159292), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22326'}), confidence=0.5265486725663717, lift=1.263716814159292)])
# yes
# RelationRecord(items=frozenset({'POST', '22328'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22328'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'22328'}), items_add=frozenset({'POST'}), confidence=0.8839285714285715, lift=1.2672250316055627), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22328'}), confidence=0.43805309734513276, lift=1.2672250316055627)])
# yes
# RelationRecord(items=frozenset({'POST', '22423'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22423'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'22423'}), items_add=frozenset({'POST'}), confidence=0.7397260273972602, lift=1.0604921808704084), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22423'}), confidence=0.47787610619469023, lift=1.0604921808704084)])
# yes
# RelationRecord(items=frozenset({'22554', 'POST'}), support=0.3271604938271605, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22554', 'POST'}), confidence=0.3271604938271605, lift=1.0), OrderedStatistic(items_base=frozenset({'22554'}), items_add=frozenset({'POST'}), confidence=0.8760330578512397, lift=1.255905799751335), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22554'}), confidence=0.4690265486725664, lift=1.2559057997513348)])
# yes
# RelationRecord(items=frozenset({'POST', '22556'}), support=0.3271604938271605, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22556'}), confidence=0.3271604938271605, lift=1.0), OrderedStatistic(items_base=frozenset({'22556'}), items_add=frozenset({'POST'}), confidence=0.8617886178861789, lift=1.235484567235053), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22556'}), confidence=0.4690265486725664, lift=1.2354845672350527)])
# yes
# RelationRecord(items=frozenset({'22630', '22629'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22630', '22629'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'22630'}), confidence=0.8181818181818182, lift=2.325358851674641), OrderedStatistic(items_base=frozenset({'22630'}), items_add=frozenset({'22629'}), confidence=0.868421052631579, lift=2.325358851674641)])
# yes
# RelationRecord(items=frozenset({'POST', '22629'}), support=0.31790123456790126, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22629'}), confidence=0.31790123456790126, lift=1.0), OrderedStatistic(items_base=frozenset({'22629'}), items_add=frozenset({'POST'}), confidence=0.8512396694214877, lift=1.2203612959847876), OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22629'}), confidence=0.4557522123893806, lift=1.2203612959847876)])

# %%
min_sup = 0.35
frequent_q6_eu = list(apriori(transactions_q6_eu,min_support = min_sup))
frequent_q6_eu.sort(reverse = True, key=support)

printFrequentItemsets(frequent_q6_eu, data_q6_eu, 2)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'POST', '22326'})
# support:  36.7283950617284
# POST
# {nan, 'POSTAGE'}
# 22326
# {'ROUND SNACK BOXES SET OF4 WOODLAND '}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'POST', '22326'}), confidence=0.36728395061728397, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22326'}), items_add=frozenset({'POST'}), confidence=0.8814814814814815, lift=1.263716814159292)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'POST'}), items_add=frozenset({'22326'}), confidence=0.5265486725663717, lift=1.263716814159292)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Q6-Q3 ของช่วงเวลา ตรุษจีน ในทวีป Asia  (15 Jan - 15 Feb)

# %%
data_q6_cny = data_q6[(data_q6['CNY_Period']) & (data_q6['Continent'] == 'Asia')]

# %%
data_q6_cny
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 69623    541975     22620          4 TRADITIONAL SPINNING TOPS        60
# 69624    541975    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA         6
# 69625    541975    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE         6
# 69626    541975     16236                 KITTY PENCIL ERASERS        28
# 69627    541975     21058               PARTY INVITES WOODLAND        12
# ...         ...       ...                                  ...       ...
# 89595    543911    47590B          PINK HAPPY BIRTHDAY BUNTING        12
# 89596    543911     22117     METAL SIGN HER DINNER IS SERVED         12
# 89597    543911     82567            AIRLINE LOUNGE,METAL SIGN        12
# 89598    543911     21910                  WAY OUT METAL SIGN         12
# 89599    543911     21911                   GARDEN METAL SIGN         12
#
#       InvoiceDate  UnitPrice  CustomerID               Country Continent  \
# 69623   1/24/2011       1.25         NaN             Hong Kong      Asia
# 69624   1/24/2011       3.75         NaN             Hong Kong      Asia
# 69625   1/24/2011       3.75         NaN             Hong Kong      Asia
# 69626   1/24/2011       0.21         NaN             Hong Kong      Asia
# 69627   1/24/2011       0.85         NaN             Hong Kong      Asia
# ...           ...        ...         ...                   ...       ...
# 89595   2/14/2011       5.45     17829.0  United Arab Emirates      Asia
# 89596   2/14/2011       2.95     17829.0  United Arab Emirates      Asia
# 89597   2/14/2011       2.10     17829.0  United Arab Emirates      Asia
# 89598   2/14/2011       1.65     17829.0  United Arab Emirates      Asia
# 89599   2/14/2011       1.65     17829.0  United Arab Emirates      Asia
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period InvoiceTime  \
# 69623 2011-01-24 14:24:00            False        True     False       14:24
# 69624 2011-01-24 14:24:00            False        True     False       14:24
# 69625 2011-01-24 14:24:00            False        True     False       14:24
# 69626 2011-01-24 14:24:00            False        True     False       14:24
# 69627 2011-01-24 14:24:00            False        True     False       14:24
# ...                   ...              ...         ...       ...         ...
# 89595 2011-02-14 12:46:00            False        True      True       12:46
# 89596 2011-02-14 12:46:00            False        True      True       12:46
# 89597 2011-02-14 12:46:00            False        True      True       12:46
# 89598 2011-02-14 12:46:00            False        True      True       12:46
# 89599 2011-02-14 12:46:00            False        True      True       12:46
#
#       month day  year
# 69623     1  24  2011
# 69624     1  24  2011
# 69625     1  24  2011
# 69626     1  24  2011
# 69627     1  24  2011
# ...     ...  ..   ...
# 89595     2  14  2011
# 89596     2  14  2011
# 89597     2  14  2011
# 89598     2  14  2011
# 89599     2  14  2011
#
# [273 rows x 17 columns]

# %%
transactions_q6_cny = data_q6_cny.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_q6_cny
# Out:
# Country               month
# Hong Kong             1        [22620, 85183B, 85183A, 16236, 21058, 21967, 2...
# Japan                 02       [22407, 22406, 22405, 21745, 22496, 22495, 224...
# Lebanon               1        [82551, 21165, 82600, 21754, 21756, 82482, 824...
# Singapore             1        [21519, 22697, 22699, 22343, 22344, 22345, 223...
# United Arab Emirates  2        [21485, 48138, 85150, 82552, 82551, 82583, 224...
# Name: StockCode, dtype: object

# %%
len(transactions_q6_cny[1])
# Out:
# 85

# %%
min_sup = 0.4
frequentItemsets = list(apriori(transactions_q6_cny,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>3:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'20682', '22202', '22551', '22203'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20682', '22202', '22551', '22203'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22551', '22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'20682', '22551', '22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'20682', '22202', '22551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'20682', '22202', '22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20682', '22202'}), items_add=frozenset({'22551', '22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20682', '22203'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20682', '22551'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'20682', '22551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'20682', '22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22551', '22203'}), items_add=frozenset({'20682', '22202'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20682', '22202', '22203'}), items_add=frozenset({'22551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20682', '22202', '22551'}), items_add=frozenset({'22203'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20682', '22551', '22203'}), items_add=frozenset({'22202'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22202', '22551', '22203'}), items_add=frozenset({'20682'}), confidence=1.0, lift=2.5)])
# yes
# RelationRecord(items=frozenset({'21216', '20725', '22620', '21439'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21216', '20725', '22620', '21439'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'20725'}), items_add=frozenset({'21216', '22620', '21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216'}), items_add=frozenset({'20725', '22620', '21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21439'}), items_add=frozenset({'21216', '20725', '22620'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22620'}), items_add=frozenset({'21216', '20725', '21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216', '20725'}), items_add=frozenset({'22620', '21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20725', '21439'}), items_add=frozenset({'21216', '22620'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20725', '22620'}), items_add=frozenset({'21216', '21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216', '21439'}), items_add=frozenset({'20725', '22620'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216', '22620'}), items_add=frozenset({'20725', '21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22620', '21439'}), items_add=frozenset({'21216', '20725'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216', '20725', '21439'}), items_add=frozenset({'22620'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216', '20725', '22620'}), items_add=frozenset({'21439'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'20725', '22620', '21439'}), items_add=frozenset({'21216'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21216', '22620', '21439'}), items_add=frozenset({'20725'}), confidence=1.0, lift=2.5)])
# yes
# RelationRecord(items=frozenset({'82552', '21165', '82551', '85150'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82552', '21165', '82551', '85150'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'85150', '82552', '82551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'21165', '82552', '85150'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'21165', '82551', '85150'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21165', '82552', '82551'}), confidence=0.6666666666666667, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'21165', '82551'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'85150', '82551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21165', '85150'}), items_add=frozenset({'82552', '82551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'82552', '82551'}), items_add=frozenset({'21165', '85150'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'85150', '82551'}), items_add=frozenset({'21165', '82552'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'21165', '82551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'82552', '21165', '82551'}), items_add=frozenset({'85150'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'21165', '82551', '85150'}), items_add=frozenset({'82552'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21165', '82552', '85150'}), items_add=frozenset({'82551'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'82552', '85150', '82551'}), items_add=frozenset({'21165'}), confidence=1.0, lift=2.5)])
# yes
# RelationRecord(items=frozenset({'21756', '22960', '85150', '22957'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21756', '22960', '85150', '22957'}), confidence=0.4, lift=1.0), OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'22957', '85150', '22960'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'21756', '85150', '22960'}), confidence=0.6666666666666667, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'21756', '85150', '22957'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21756', '22960', '22957'}), confidence=0.6666666666666667, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'21756', '22957'}), items_add=frozenset({'85150', '22960'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'22957', '85150'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21756', '85150'}), items_add=frozenset({'22957', '22960'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'21756', '85150'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'22957', '85150'}), items_add=frozenset({'21756', '22960'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'21756', '22957'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21756', '22960', '22957'}), items_add=frozenset({'85150'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'21756', '85150', '22957'}), items_add=frozenset({'22960'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'21756', '85150', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '85150', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=2.5)])

# %%
min_sup = 0.4
frequent_q6_cny = list(apriori(transactions_q6_cny,min_support = min_sup))
frequent_q6_cny.sort(reverse = True, key=support)

printFrequentItemsets(frequent_q6_cny, data_q6_cny, 4)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'20682', '22202', '22551', '22203'})
# support:  40.0
# 20682
# {'RED RETROSPOT CHILDRENS UMBRELLA'}
# 22202
# {'MILK PAN PINK POLKADOT'}
# 22551
# {'PLASTERS IN TIN SPACEBOY'}
# 22203
# {'MILK PAN RED RETROSPOT'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20682', '22202', '22551', '22203'}), confidence=0.4, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22551', '22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'20682', '22551', '22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'20682', '22202', '22551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'20682', '22202', '22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22202'}), items_add=frozenset({'22551', '22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22203'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22551'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'20682', '22551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'20682', '22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22551', '22203'}), items_add=frozenset({'20682', '22202'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22202', '22203'}), items_add=frozenset({'22551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22202', '22551'}), items_add=frozenset({'22203'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20682', '22551', '22203'}), items_add=frozenset({'22202'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22202', '22551', '22203'}), items_add=frozenset({'20682'}), confidence=1.0, lift=2.5)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'21216', '20725', '22620', '21439'})
# support:  40.0
# 21216
# {'SET 3 RETROSPOT TEA,COFFEE,SUGAR'}
# 20725
# {'LUNCH BAG RED RETROSPOT'}
# 22620
# {'4 TRADITIONAL SPINNING TOPS'}
# 21439
# {'BASKET OF TOADSTOOLS'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21216', '20725', '22620', '21439'}), confidence=0.4, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20725'}), items_add=frozenset({'21216', '22620', '21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216'}), items_add=frozenset({'20725', '22620', '21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21439'}), items_add=frozenset({'21216', '20725', '22620'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22620'}), items_add=frozenset({'21216', '20725', '21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216', '20725'}), items_add=frozenset({'22620', '21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20725', '21439'}), items_add=frozenset({'21216', '22620'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20725', '22620'}), items_add=frozenset({'21216', '21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216', '21439'}), items_add=frozenset({'20725', '22620'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216', '22620'}), items_add=frozenset({'20725', '21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22620', '21439'}), items_add=frozenset({'21216', '20725'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216', '20725', '21439'}), items_add=frozenset({'22620'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216', '20725', '22620'}), items_add=frozenset({'21439'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20725', '22620', '21439'}), items_add=frozenset({'21216'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21216', '22620', '21439'}), items_add=frozenset({'20725'}), confidence=1.0, lift=2.5)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'82552', '21165', '82551', '85150'})
# support:  40.0
# 82552
# {'WASHROOM METAL SIGN'}
# 21165
# {'BEWARE OF THE CAT METAL SIGN '}
# 82551
# {'LAUNDRY 15C METAL SIGN'}
# 85150
# {'LADIES & GENTLEMEN METAL SIGN'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82552', '21165', '82551', '85150'}), confidence=0.4, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'85150', '82552', '82551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'21165', '82552', '85150'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'21165', '82551', '85150'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21165', '82552', '82551'}), confidence=0.6666666666666667, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82551'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'85150', '82551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '85150'}), items_add=frozenset({'82552', '82551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552', '82551'}), items_add=frozenset({'21165', '85150'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150', '82551'}), items_add=frozenset({'21165', '82552'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'21165', '82551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552', '21165', '82551'}), items_add=frozenset({'85150'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82551', '85150'}), items_add=frozenset({'82552'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21165', '82552', '85150'}), items_add=frozenset({'82551'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'82552', '85150', '82551'}), items_add=frozenset({'21165'}), confidence=1.0, lift=2.5)
# ------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# frozenset({'21756', '22960', '85150', '22957'})
# support:  40.0
# 21756
# {'BATH BUILDING BLOCK WORD'}
# 22960
# {'JAM MAKING SET WITH JARS'}
# 85150
# {'LADIES & GENTLEMEN METAL SIGN'}
# 22957
# {'SET 3 PAPER VINTAGE CHICK PAPER EGG'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21756', '22960', '85150', '22957'}), confidence=0.4, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'22957', '85150', '22960'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'21756', '85150', '22960'}), confidence=0.6666666666666667, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'21756', '85150', '22957'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21756', '22960', '22957'}), confidence=0.6666666666666667, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '22957'}), items_add=frozenset({'85150', '22960'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'22957', '85150'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '85150'}), items_add=frozenset({'22957', '22960'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'21756', '85150'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '85150'}), items_add=frozenset({'21756', '22960'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'21756', '22957'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '22960', '22957'}), items_add=frozenset({'85150'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '85150', '22957'}), items_add=frozenset({'22960'}), confidence=1.0, lift=2.5)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21756', '85150', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '85150', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=2.5)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Q6-Q4 ของช่วงเวลา  Christmas & New Year ในทวีป Europe (1 Dec - 31 Dec)

# %%
data_q6_eu_xny = data_q6[(data_q6['Xmask_NY_Period']) & (data_q6['Continent'] == 'Europe')]

# %%
data_q6_eu_xny
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period  \
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
#        InvoiceDate1 InvoiceTime month day  year
# 0        12/01/2010       08:26    12  01  2010
# 1        12/01/2010       08:26    12  01  2010
# 2        12/01/2010       08:26    12  01  2010
# 3        12/01/2010       08:26    12  01  2010
# 4        12/01/2010       08:26    12  01  2010
# ...             ...         ...   ...  ..   ...
# 541904   12/09/2011       12:50    12  09  2011
# 541905   12/09/2011       12:50    12  09  2011
# 541906   12/09/2011       12:50    12  09  2011
# 541907   12/09/2011       12:50    12  09  2011
# 541908   12/09/2011       12:50    12  09  2011
#
# [66688 rows x 18 columns]

# %%
transactions_q6_eu_xny = data_q6_eu_xny.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_q6_eu_xny
# Out:
# Country          month
# Austria          12       [37449, 37446, 22962, 21428, 22113, 22313, 223...
# Belgium          12       [84375, 21217, 21212, 21977, 22417, 21975, 219...
# Channel Islands  12       [22690, 21955, 20685, 21523, 21169, 22112, 214...
# Cyprus           12       [85123A, 21031, 21026, 21025, 21032, 21030, 21...
# Denmark          12       [22847, 22779, 22331, 22365, 22673, 22670, 825...
# EIRE             12       [22968, 85071A, 85071C, 22355, 21579, 21576, 2...
# Finland          12       [84992, 22951, 84991, 84991, 21213, 21213, 226...
# France           12       [22728, 22727, 22726, 21724, 21883, 10002, 217...
# Germany          12       [22809, 84347, 84945, 22242, 22244, 22243, 474...
# Greece           12       [POST, 20685, 22941, 22816, 22966, 20725, 2072...
# Iceland          12       [85116, 22375, 71477, 22492, 22771, 22772, 227...
# Italy            12       [22791, 21287, 79337, 85111, 85038, 22809, 228...
# Lithuania        12       [22409, 21915, 15056BL, 15056N, 20679, 20686, ...
# Netherlands      12       [22867, POST, 21981, 21986, 22720, 21931, 2261...
# Norway           12       [84692, 22444, 22899, 21156, 22556, 22555, 225...
# Poland           12       [21733, 21232, 37446, 37448, 21700, 22844, 229...
# Portugal         12       [21992, 22383, 20728, 20658, 20669, POST, 2072...
# Spain            12       [22383, 22384, 20727, 20725, 20728, 22504, 222...
# Sweden           12       [85232B, 84077, 22951, 22417, 21977, 84992, 21...
# Switzerland      12       [22326, 22554, 21731, 20677, 20750, POST, 2283...
# United Kingdom   12       [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# Name: StockCode, dtype: object

# %%
transactions_q6_eu_xny[1]
# Out:
# ['84375',
#  '21217',
#  '21212',
#  '21977',
#  '22417',
#  '21975',
#  '21976',
#  '22551',
#  '85099B',
#  '22355',
#  '84992',
#  'POST',
#  '22801',
#  '22845',
#  '22060',
#  '22423',
#  '22619',
#  '21135',
#  '21717',
#  '22451',
#  '22770',
#  '22666',
#  'POST',
#  '22630',
#  '21880',
#  '21879',
#  '22390',
#  '22504',
#  '22740',
#  '22754',
#  '22755',
#  '22667',
#  '22666',
#  '84906',
#  '46000U',
#  '22629',
#  '22355',
#  '22356',
#  '20719',
#  '20724',
#  'POST',
#  '21258',
#  '20685',
#  '22390',
#  '22396',
#  '85169A',
#  '85169D',
#  '85184C',
#  '20723',
#  '22661',
#  '21135',
#  '22098',
#  '21749',
#  '22859',
#  '85232A',
#  '84879',
#  '85170D',
#  'POST',
#  '21121',
#  '21122',
#  '21124',
#  '21125',
#  '21126',
#  '21123',
#  '21918',
#  '22539',
#  '22544',
#  '22540',
#  '22547',
#  '21703',
#  '20973',
#  '20974',
#  '20975',
#  '16045',
#  '22489',
#  '84692',
#  '21212',
#  '21213',
#  '22417',
#  '21975',
#  '22491',
#  '22492',
#  '22080',
#  '22082',
#  '22722',
#  '22315',
#  '22090',
#  '21086',
#  '21987',
#  '21094',
#  '21988',
#  '21080',
#  '21989',
#  '22316',
#  'POST',
#  '21499',
#  '21500',
#  '16169M',
#  '21498',
#  '21495',
#  '22704',
#  '22046',
#  '22045',
#  '22706',
#  '22707',
#  '22708',
#  '23545',
#  '16156L',
#  '16156S',
#  '16161U',
#  '22908',
#  '22613',
#  '22712',
#  '21199',
#  '21508',
#  '22716',
#  '21380',
#  '21207',
#  '21126',
#  '21197',
#  '22907',
#  'POST',
#  '23576',
#  '23562',
#  '22423',
#  '23007',
#  '23241',
#  '21135',
#  '22944',
#  '22959',
#  '16161P',
#  '22666',
#  '23243',
#  '21499',
#  '23173',
#  '23175',
#  '23174',
#  '23170',
#  '21218',
#  '22624',
#  '22915',
#  'POST',
#  '23238',
#  '23237',
#  '22328',
#  '23244',
#  '23254',
#  '23256',
#  '23255',
#  '84997D',
#  '23290',
#  '23292',
#  '20749',
#  '20750',
#  '23389',
#  '23390',
#  '23391',
#  '23204',
#  '21931',
#  '23199',
#  '23202',
#  '85099B',
#  '23203',
#  '22816',
#  '22908',
#  '23369',
#  '21704',
#  '22549',
#  '23569',
#  '23598',
#  '23264',
#  'POST',
#  '79190B',
#  '79190A',
#  '22915',
#  '22151',
#  '22632',
#  '22865',
#  '20718',
#  '79191B',
#  '71459',
#  '84945',
#  '22356',
#  '20724',
#  '23204',
#  '21108',
#  '22252',
#  '22807',
#  'POST']

# %%
min_sup = 0.3
frequentItemsets = list(apriori(transactions_q6_eu_xny,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>3:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22558', '21481', '21212', '21156'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22558', '21481', '21212', '21156'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21156'}), items_add=frozenset({'22558', '21212', '21481'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21212'}), items_add=frozenset({'22558', '21156', '21481'}), confidence=0.7777777777777778, lift=2.3333333333333335), OrderedStatistic(items_base=frozenset({'21481'}), items_add=frozenset({'22558', '21212', '21156'}), confidence=0.875, lift=2.625), OrderedStatistic(items_base=frozenset({'22558'}), items_add=frozenset({'21156', '21212', '21481'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21212', '21156'}), items_add=frozenset({'22558', '21481'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21481', '21156'}), items_add=frozenset({'22558', '21212'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22558', '21156'}), items_add=frozenset({'21212', '21481'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21212', '21481'}), items_add=frozenset({'22558', '21156'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22558', '21212'}), items_add=frozenset({'21156', '21481'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22558', '21481'}), items_add=frozenset({'21212', '21156'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21481', '21212', '21156'}), items_add=frozenset({'22558'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22558', '21212', '21156'}), items_add=frozenset({'21481'}), confidence=1.0, lift=2.625), OrderedStatistic(items_base=frozenset({'22558', '21481', '21156'}), items_add=frozenset({'21212'}), confidence=1.0, lift=2.3333333333333335), OrderedStatistic(items_base=frozenset({'22558', '21212', '21481'}), items_add=frozenset({'21156'}), confidence=1.0, lift=3.0)])

# %%
min_sup = 0.3
frequent_q6_eu_xny = list(apriori(transactions_q6_eu_xny,min_support = min_sup))
frequent_q6_eu_xny.sort(reverse = True, key=support)

printFrequentItemsets(frequent_q6_eu_xny, data_q6_eu_xny, 4)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'22558', '21481', '21212', '21156'})
# support:  33.33333333333333
# 22558
# {'CLOTHES PEGS RETROSPOT PACK 24 '}
# 21481
# {'FAWN BLUE HOT WATER BOTTLE'}
# 21212
# {'PACK OF 72 RETROSPOT CAKE CASES'}
# 21156
# {'RETROSPOT CHILDRENS APRON'}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22558', '21481', '21212', '21156'}), confidence=0.3333333333333333, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21156'}), items_add=frozenset({'22558', '21212', '21481'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21212'}), items_add=frozenset({'22558', '21156', '21481'}), confidence=0.7777777777777778, lift=2.3333333333333335)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21481'}), items_add=frozenset({'22558', '21212', '21156'}), confidence=0.875, lift=2.625)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558'}), items_add=frozenset({'21156', '21212', '21481'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21212', '21156'}), items_add=frozenset({'22558', '21481'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21481', '21156'}), items_add=frozenset({'22558', '21212'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558', '21156'}), items_add=frozenset({'21212', '21481'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21212', '21481'}), items_add=frozenset({'22558', '21156'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558', '21212'}), items_add=frozenset({'21156', '21481'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558', '21481'}), items_add=frozenset({'21212', '21156'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'21481', '21212', '21156'}), items_add=frozenset({'22558'}), confidence=1.0, lift=3.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558', '21212', '21156'}), items_add=frozenset({'21481'}), confidence=1.0, lift=2.625)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558', '21481', '21156'}), items_add=frozenset({'21212'}), confidence=1.0, lift=2.3333333333333335)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22558', '21212', '21481'}), items_add=frozenset({'21156'}), confidence=1.0, lift=3.0)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Q6-Q5  ของวันวาเลนไทน์

# %%
data_q6_v = data_q6[data_q6['V_Period']]

# %%
data_q6_v
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 88847    543821     22926      IVORY GIANT GARDEN THERMOMETER         2
# 88848    543821     22928     YELLOW GIANT GARDEN THERMOMETER         2
# 88849    543821     22925       BLUE GIANT GARDEN THERMOMETER         2
# 88850    543821     85175               CACTI T-LIGHT CANDLES        16
# 88851    543821     22456     NATURAL SLATE CHALKBOARD LARGE          3
# ...         ...       ...                                 ...       ...
# 89949    543979     22196        SMALL HEART MEASURING SPOONS         1
# 89950    543979     21889              WOODEN BOX OF DOMINOES         1
# 89951    543979     85176          SEWING SUSAN 21 NEEDLE SET         1
# 89952    543979     37446  MINI CAKE STAND WITH HANGING CAKES         1
# 89953    543979     21657     MILK BOTTLE WITH GLASS STOPPER          1
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 88847   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88848   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88849   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88850   2/14/2011 9:24       0.42     17667.0  United Kingdom    Europe
# 88851   2/14/2011 9:24       4.95     17667.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 89949  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89950  2/14/2011 15:43       1.25     14606.0  United Kingdom    Europe
# 89951  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89952  2/14/2011 15:43       1.45     14606.0  United Kingdom    Europe
# 89953  2/14/2011 15:43       6.95     14606.0  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period InvoiceDate1  \
# 88847 2011-02-14 09:24:00            False        True      True    2/14/2011
# 88848 2011-02-14 09:24:00            False        True      True    2/14/2011
# 88849 2011-02-14 09:24:00            False        True      True    2/14/2011
# 88850 2011-02-14 09:24:00            False        True      True    2/14/2011
# 88851 2011-02-14 09:24:00            False        True      True    2/14/2011
# ...                   ...              ...         ...       ...          ...
# 89949 2011-02-14 15:43:00            False        True      True    2/14/2011
# 89950 2011-02-14 15:43:00            False        True      True    2/14/2011
# 89951 2011-02-14 15:43:00            False        True      True    2/14/2011
# 89952 2011-02-14 15:43:00            False        True      True    2/14/2011
# 89953 2011-02-14 15:43:00            False        True      True    2/14/2011
#
#       InvoiceTime month day  year
# 88847        9:24     2  14  2011
# 88848        9:24     2  14  2011
# 88849        9:24     2  14  2011
# 88850        9:24     2  14  2011
# 88851        9:24     2  14  2011
# ...           ...   ...  ..   ...
# 89949       15:43     2  14  2011
# 89950       15:43     2  14  2011
# 89951       15:43     2  14  2011
# 89952       15:43     2  14  2011
# 89953       15:43     2  14  2011
#
# [1087 rows x 18 columns]

# %%
transactions_q6_v = data_q6_v.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_q6_v
# Out:
# Country               month
# EIRE                  2        [22723, 22722, 22720, 22899, 22567, 84987, 228...
# Germany               2        [22788, 22957, 21621, 22722, 22384, 21791, 217...
# Spain                 2        [22139, 20973, 22585, 22960, 84380, 84378, 229...
# United Arab Emirates  2        [21485, 48138, 85150, 82552, 82551, 82583, 224...
# United Kingdom        2        [22926, 22928, 22925, 85175, 22456, 22854, 227...
# Name: StockCode, dtype: object

# %%
transactions_q6_v[1]
# Out:
# ['22788',
#  '22957',
#  '21621',
#  '22722',
#  '22384',
#  '21791',
#  '21716',
#  'POST',
#  '22355',
#  '20719',
#  '20723',
#  '17003',
#  '22331',
#  '22385',
#  '84569B',
#  '21915',
#  '22560',
#  '21914',
#  '22957',
#  '22077',
#  '21937',
#  '22711',
#  '22630',
#  '20726',
#  '20728',
#  '22326',
#  '22383',
#  '22662',
#  '22813',
#  '22729',
#  '22727',
#  '22725',
#  '22860',
#  '22857',
#  '22661',
#  '23233',
#  '22966',
#  'POST']

# %%
min_sup = 0.6
frequentItemsets = list(apriori(transactions_q6_v,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>6:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'20726', '22661', '20719', '22662', '20728', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '20726', '22662', '20728', '22722', '22383', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22662', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22662', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'20726', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '20726', '22662', '20728', '22957', '22383', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22661', '20719', '20728', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20719', '20726', '20728', '22722', '22957', '22383', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22957', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22662', '20719', '20728', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20726', '20719', '20728', '22722', '22957', '22383'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22662', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22662', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22662', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22957', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22957', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22662', '20719', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22662', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726', '22957', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726', '22957', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726', '22957', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22661', '22662', '20719', '20728', '22722'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20726', '20719', '20728', '22722', '22957', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '22662', '20719', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22661', '22662', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20719'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22661', '22662', '20719', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20726', '20719', '22722', '22957', '22383', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22957', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22957', '22661', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '22383'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20719'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '22383'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'22957', '22661', '22662', '20719', '20728', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20719', '20728', '22722', '22957', '22383', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'22957', '22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'22957', '22662', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22957', '22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'22957', '22662', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'22957', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'22957', '22661', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'22957', '22662', '20719', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '22383'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '22722'}), items_add=frozenset({'22957', '22661', '22662', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '22383'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22661', '22662', '20728', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22662', '20726', '20728', '22722', '22957', '22383', '22661'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '22662', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'20726', '22957', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '22383'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '22383'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667) ...
# yes
# RelationRecord(items=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22722', '22383'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22722', '22383'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '20719', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '20719', '22662', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667), OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722', '22383'}), co ...

# %%
min_sup = 0.59
frequent_q6_v = list(apriori(transactions_q6_v,min_support = min_sup))
frequent_q6_v.sort(reverse = True, key=support)

printFrequentItemsets(frequent_q6_v, data_q6_v, 8)
# Out:
# ----------------------------------------------------------------------------------------------------
# frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22722', '22383'})
# support:  60.0
# 20726
# {'LUNCH BAG WOODLAND'}
# 22957
# {'SET 3 PAPER VINTAGE CHICK PAPER EGG'}
# 22661
# {'CHARLOTTE BAG DOLLY GIRL DESIGN'}
# 20719
# {'WOODLAND CHARLOTTE BAG'}
# 22662
# {'LUNCH BAG DOLLY GIRL DESIGN'}
# 20728
# {'LUNCH BAG CARS BLUE'}
# 22722
# {'SET OF 6 SPICE TINS PANTRY DESIGN'}
# 22383
# {'LUNCH BAG SUKI  DESIGN '}
# ------------------------------
# OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22722', '22383'}), confidence=0.6, lift=1.0)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'20726', '22661', '20719', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661'}), items_add=frozenset({'22957', '20719', '22662', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22722'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20728', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22722', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22661'}), items_add=frozenset({'20726', '22957', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22722', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661'}), items_add=frozenset({'20726', '22662', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662'}), items_add=frozenset({'20726', '22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22722'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '20728'}), items_add=frozenset({'22957', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22383'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22661'}), items_add=frozenset({'22957', '22662', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20726'}), items_add=frozenset({'22957', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22722'}), items_add=frozenset({'22957', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20726'}), items_add=frozenset({'22661', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20728', '22661'}), items_add=frozenset({'20726', '22957', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22722', '20728'}), items_add=frozenset({'20726', '22957', '22661', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20728'}), items_add=frozenset({'20726', '22661', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22383'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383', '22722'}), items_add=frozenset({'20726', '22957', '22661', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22383'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22661'}), items_add=frozenset({'20726', '22957', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22722', '22661'}), items_add=frozenset({'20726', '22957', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22661'}), items_add=frozenset({'20726', '22662', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22722'}), items_add=frozenset({'20726', '22957', '22661', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22957'}), items_add=frozenset({'20726', '22661', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22722'}), items_add=frozenset({'20726', '22661', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '20728', '22661'}), items_add=frozenset({'22957', '20719', '22662', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '20728'}), items_add=frozenset({'22957', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '20728', '22722'}), items_add=frozenset({'22957', '22661', '20719', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '20728'}), items_add=frozenset({'22661', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383', '22661'}), items_add=frozenset({'22957', '20719', '22662', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22383'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383', '22722'}), items_add=frozenset({'22957', '22661', '20719', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22383'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22661'}), items_add=frozenset({'22957', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22722'}), items_add=frozenset({'22957', '20719', '22662', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22661'}), items_add=frozenset({'22662', '20719', '22722', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22722'}), items_add=frozenset({'22957', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20726'}), items_add=frozenset({'22661', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22722'}), items_add=frozenset({'22661', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '20728', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '20728', '22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22662'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20728', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22722', '20728', '22661'}), items_add=frozenset({'20726', '22957', '20719', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20728', '22661'}), items_add=frozenset({'20726', '22662', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22722', '20728'}), items_add=frozenset({'20726', '22957', '22661', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20728'}), items_add=frozenset({'20726', '22661', '20719', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22722', '20728'}), items_add=frozenset({'20726', '22661', '22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383', '22661'}), items_add=frozenset({'20726', '22957', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '22661', '22722'}), items_add=frozenset({'20726', '22957', '20719', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383', '22661'}), items_add=frozenset({'20726', '22662', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383', '22722'}), items_add=frozenset({'20726', '22957', '22661', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22383'}), items_add=frozenset({'20726', '22661', '20719', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383', '22722'}), items_add=frozenset({'20726', '22661', '22662', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22722', '22661'}), items_add=frozenset({'20726', '22957', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22661'}), items_add=frozenset({'20726', '20719', '20728', '22722', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22722', '22661'}), items_add=frozenset({'20726', '22662', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22722'}), items_add=frozenset({'20726', '22661', '20719', '20728', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22383', '20728'}), items_add=frozenset({'22957', '22662', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '20728', '22661'}), items_add=frozenset({'22957', '22662', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20726', '20728'}), items_add=frozenset({'22957', '22722', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '20728', '22722'}), items_add=frozenset({'22957', '22662', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20726', '20728'}), items_add=frozenset({'22662', '22722', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22383', '22661'}), items_add=frozenset({'22957', '22662', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20726', '22383'}), items_add=frozenset({'22957', '20728', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22383', '22722'}), items_add=frozenset({'22957', '20728', '22662', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20726', '22383'}), items_add=frozenset({'20728', '22662', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20726', '22661'}), items_add=frozenset({'22957', '22722', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '20726', '22661', '22722'}), items_add=frozenset({'22957', '22662', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20726', '22661'}), items_add=frozenset({'22662', '22722', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20726', '22722'}), items_add=frozenset({'22957', '20728', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20726', '22957'}), items_add=frozenset({'20728', '22722', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20726', '22722'}), items_add=frozenset({'20728', '22662', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383', '20728', '22661'}), items_add=frozenset({'22957', '22662', '20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22383', '20728'}), items_add=frozenset({'22957', '20726', '22661', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383', '20728', '22722'}), items_add=frozenset({'22957', '22662', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22383', '20728'}), items_add=frozenset({'22662', '20726', '22661', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20728', '22661'}), items_add=frozenset({'22957', '20726', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22722', '20728', '22661'}), items_add=frozenset({'22957', '22662', '20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20728', '22661'}), items_add=frozenset({'22662', '20726', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22722', '20728'}), items_add=frozenset({'22957', '20726', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20728', '22957'}), items_add=frozenset({'20726', '22383', '22661', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22722', '20728'}), items_add=frozenset({'22662', '20726', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22383', '22661'}), items_add=frozenset({'22957', '20726', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20719', '22383', '22661', '22722'}), items_add=frozenset({'22957', '22662', '20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22383', '22661'}), items_add=frozenset({'22662', '20726', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22383', '22722'}), items_add=frozenset({'22957', '20728', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22383', '22957'}), items_add=frozenset({'20728', '20726', '22661', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22383', '22722'}), items_add=frozenset({'20728', '22662', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22722', '22661'}), items_add=frozenset({'22957', '20726', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22661', '22957'}), items_add=frozenset({'20726', '22383', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '22722', '22661'}), items_add=frozenset({'22662', '20726', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '22722', '22957'}), items_add=frozenset({'20728', '20726', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383', '20728', '22661'}), items_add=frozenset({'22957', '20719', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22383', '20728'}), items_add=frozenset({'22957', '20719', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383', '20728', '22722'}), items_add=frozenset({'22957', '20719', '22662', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22383', '20728'}), items_add=frozenset({'22662', '20719', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '20728', '22661'}), items_add=frozenset({'22957', '20719', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22722', '20728', '22661'}), items_add=frozenset({'22957', '20719', '22383', '22662'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '20728', '22661'}), items_add=frozenset({'22662', '20719', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '20728', '22722'}), items_add=frozenset({'22957', '20719', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20726', '20728'}), items_add=frozenset({'20719', '22722', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '20728', '22722'}), items_add=frozenset({'22662', '20719', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22383', '22661'}), items_add=frozenset({'22957', '20719', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22383', '22661', '22722'}), items_add=frozenset({'22957', '20719', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22383', '22661'}), items_add=frozenset({'22662', '20719', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22383', '22722'}), items_add=frozenset({'22957', '20728', '20719', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20726', '22383'}), items_add=frozenset({'20728', '20719', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22383', '22722'}), items_add=frozenset({'22662', '20728', '20719', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20726', '22661', '22722'}), items_add=frozenset({'22957', '20719', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20726', '22661'}), items_add=frozenset({'20719', '22722', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20726', '22661', '22722'}), items_add=frozenset({'22662', '20719', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20726', '22722'}), items_add=frozenset({'20728', '20719', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383', '20728', '22661'}), items_add=frozenset({'22957', '20719', '20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22383', '22722', '20728', '22661'}), items_add=frozenset({'22957', '20719', '20726', '22662'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383', '20728', '22661'}), items_add=frozenset({'22662', '20719', '20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383', '20728', '22722'}), items_add=frozenset({'22957', '20719', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22383', '20728'}), items_add=frozenset({'20719', '20726', '22661', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383', '20728', '22722'}), items_add=frozenset({'22662', '20719', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22722', '20728', '22661'}), items_add=frozenset({'22957', '20719', '20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20728', '22661'}), items_add=frozenset({'20719', '20726', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22722', '20728', '22661'}), items_add=frozenset({'22662', '20719', '20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22722', '20728'}), items_add=frozenset({'20719', '20726', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '22383', '22661', '22722'}), items_add=frozenset({'22957', '20719', '20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22383', '22661'}), items_add=frozenset({'20719', '20726', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22383', '22661', '22722'}), items_add=frozenset({'22662', '20719', '20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22383', '22722'}), items_add=frozenset({'20728', '20719', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '22722', '22661'}), items_add=frozenset({'20719', '20726', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '20719', '20728', '22383'}), items_add=frozenset({'22957', '22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22662', '20719', '20728', '22383'}), items_add=frozenset({'22957', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22957', '22662', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '20719', '20728', '22383'}), items_add=frozenset({'22662', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20719', '20728'}), items_add=frozenset({'22957', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '20719', '22722', '20728'}), items_add=frozenset({'22957', '22662', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '20728'}), items_add=frozenset({'22662', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22662', '20719', '20728', '22722'}), items_add=frozenset({'22957', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '20728'}), items_add=frozenset({'22722', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '20719', '20728', '22722'}), items_add=frozenset({'22662', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20719', '22383'}), items_add=frozenset({'22957', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '20719', '22722', '22383'}), items_add=frozenset({'22957', '22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '22383'}), items_add=frozenset({'22662', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22662', '20719', '22722', '22383'}), items_add=frozenset({'22957', '20728', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '22383'}), items_add=frozenset({'20728', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '20719', '22722', '22383'}), items_add=frozenset({'20728', '22662', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20719', '22722'}), items_add=frozenset({'22957', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20719'}), items_add=frozenset({'22722', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '22722'}), items_add=frozenset({'22662', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '22722'}), items_add=frozenset({'20728', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661', '22662', '20719', '20728', '22383'}), items_add=frozenset({'22957', '20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661', '20719', '22722', '20728', '22383'}), items_add=frozenset({'22957', '22662', '20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '20719', '20728', '22383'}), items_add=frozenset({'22662', '20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22662', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22957', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20719', '20728', '22383'}), items_add=frozenset({'20726', '22661', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22662', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661', '22662', '20719', '22722', '20728'}), items_add=frozenset({'22957', '20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '20728'}), items_add=frozenset({'20726', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '20719', '22722', '20728'}), items_add=frozenset({'22662', '20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20719', '22722', '20728'}), items_add=frozenset({'20726', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661', '22662', '20719', '22722', '22383'}), items_add=frozenset({'22957', '20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '22383'}), items_add=frozenset({'20726', '20728', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '20719', '22722', '22383'}), items_add=frozenset({'22662', '20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20719', '22722', '22383'}), items_add=frozenset({'20728', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '22722'}), items_add=frozenset({'20726', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20728', '22383'}), items_add=frozenset({'22957', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22722', '20728', '22383'}), items_add=frozenset({'22957', '20719', '22662'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20728', '22383'}), items_add=frozenset({'22662', '20719', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22662', '20728', '22722', '22383'}), items_add=frozenset({'22957', '20719', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20728', '22383'}), items_add=frozenset({'20719', '22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '20728', '22722', '22383'}), items_add=frozenset({'22662', '20719', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '22722', '20728'}), items_add=frozenset({'22957', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20728'}), items_add=frozenset({'20719', '22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22722', '20728'}), items_add=frozenset({'22662', '20719', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20728', '22722'}), items_add=frozenset({'20719', '22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '22722', '22383'}), items_add=frozenset({'22957', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '22383'}), items_add=frozenset({'20719', '22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22722', '22383'}), items_add=frozenset({'22662', '20719', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '22722', '22383'}), items_add=frozenset({'20728', '20719', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '22722'}), items_add=frozenset({'20719', '22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661', '22662', '22722', '20728', '22383'}), items_add=frozenset({'22957', '20719', '20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20728', '22383'}), items_add=frozenset({'20719', '20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22722', '20728', '22383'}), items_add=frozenset({'22662', '20719', '20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20728', '22722', '22383'}), items_add=frozenset({'20719', '20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '22722', '20728'}), items_add=frozenset({'20719', '20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '22722', '22383'}), items_add=frozenset({'20719', '20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '20719', '22662', '20728', '22383'}), items_add=frozenset({'22957', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22957', '22662'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '20728', '22383'}), items_add=frozenset({'22662', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22662', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22957', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '20728', '22383'}), items_add=frozenset({'22722', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22662', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20719', '20728', '22722'}), items_add=frozenset({'22957', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20719', '20728'}), items_add=frozenset({'22383', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '22722', '20728'}), items_add=frozenset({'22662', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '20728', '22722'}), items_add=frozenset({'22383', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20719', '22722', '22383'}), items_add=frozenset({'22957', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20719', '22383'}), items_add=frozenset({'22722', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '22722', '22383'}), items_add=frozenset({'22662', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '22722', '22383'}), items_add=frozenset({'20728', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20719', '22722'}), items_add=frozenset({'22383', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22661', '22662', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22957', '20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '20728', '22383'}), items_add=frozenset({'20726', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '20719', '22722', '20728', '22383'}), items_add=frozenset({'22662', '20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22662', '20719', '20728', '22722', '22383'}), items_add=frozenset({'20726', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '22722', '20728'}), items_add=frozenset({'20726', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '22722', '22383'}), items_add=frozenset({'20726', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '22662', '20728', '22722', '22383'}), items_add=frozenset({'22957', '20719'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20728', '22383'}), items_add=frozenset({'20719', '22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22722', '20728', '22383'}), items_add=frozenset({'22662', '20719'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20728', '22722', '22383'}), items_add=frozenset({'20719', '22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '22722', '20728'}), items_add=frozenset({'20719', '22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '22722', '22383'}), items_add=frozenset({'20719', '20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '22722', '20728', '22383'}), items_add=frozenset({'20719', '20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22661', '20719', '22662', '20728', '22722', '22383'}), items_add=frozenset({'22957'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '22662', '20728', '22383'}), items_add=frozenset({'22722'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22662'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22662', '20719', '20728', '22722', '22383'}), items_add=frozenset({'22661'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20719', '20728', '22722'}), items_add=frozenset({'22383'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20719', '22722', '22383'}), items_add=frozenset({'20728'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'22957', '22661', '22662', '20719', '20728', '22722', '22383'}), items_add=frozenset({'20726'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ------------------------------
# OrderedStatistic(items_base=frozenset({'20726', '22957', '22661', '22662', '20728', '22722', '22383'}), items_add=frozenset({'20719'}), confidence=1.0, lift=1.6666666666666667)
# ------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
stock_list = '20726', '22957', '22661', '20719', '22662', '20728', '22722', '22383'
ss = find_stock(stock_list)
# Out:
# 20726 : {'LUNCH BAG WOODLAND'}
# 22957 : {'SET 3 PAPER VINTAGE CHICK PAPER EGG'}
# 22661 : {'CHARLOTTE BAG DOLLY GIRL DESIGN'}
# 20719 : {'WOODLAND CHARLOTTE BAG'}
# 22662 : {'LUNCH BAG DOLLY GIRL DESIGN'}
# 20728 : {'LUNCH BAG CARS BLUE'}
# 22722 : {nan, 'SET OF 6 SPICE TINS PANTRY DESIGN'}
# 22383 : {'LUNCH BAG SUKI DESIGN ', 'LUNCH BAG SUKI  DESIGN '}

# %% [markdown]
# ### finish
